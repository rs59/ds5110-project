# %% [markdown]
# ## File 05 - Linear Regression
#
# In this file, we create a small ML pipeline based on the output from File 02 (Feature creation).
#
# We create a linear regression model, tune it, then compare it to a linear regression model created with downsampled data to see how performance compares.

# %% [markdown]
# ### Set up Spark session
#
# We can specify more options in the SparkSession creator, but currently the options are at the default settings.

# %%
# %%time
from pyspark.sql import SparkSession
from pyspark.sql import types as T
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression, LinearRegressionModel, LinearRegressionSummary
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.sql.functions import col
from pyspark.sql.functions import log
from pyspark.ml.stat import Correlation

import pandas as pd
import numpy as np
import copy

spark = SparkSession.builder \
        .appName("project") \
        .getOrCreate()

sc = spark.sparkContext
# Out:
# CPU times: user 530 ms, sys: 412 ms, total: 942 ms
# Wall time: 7.07 s

# %% [markdown]
# ### Read in dataframes for train and test sets
#
# This data should have been previously generated: we can find it in the `processed_data` folder.

# %%
# %%time
trainDF = spark.read.parquet("./processed_data/train.parquet")
testDF = spark.read.parquet("./processed_data/test.parquet")
# trainDF.show(5)
# Out:
# CPU times: user 1.81 ms, sys: 2.86 ms, total: 4.67 ms
# Wall time: 2.89 s

# %% [markdown]
# ### Set up Spark ML pipeline training for linear regression
#
# Here we decide which input columns should be used in order to create our training pipeline. To implement this step, we create the function `generatePipeline(inputCols, outputCol)`. Then, we train the pipeline using this function.

# %%
# %%time

def generatePipeline(inputCols, outputCol):
    # Select input columns for linear regression
    vecAssembler = VectorAssembler(inputCols=inputCols, outputCol="features")

    # Select output column for linear regression
    lr = LinearRegression(featuresCol="features", labelCol=outputCol)

    # The following lines (pipeline creation and fitting) replace these two commented-out lines.
    # vecTrainDF = vecAssembler.transform(trainDF)
 
    pipeline = Pipeline(stages=[vecAssembler, lr])
    return pipeline
    
pipeline = generatePipeline(inputCols, "T_total_spend")
pipelineModel = pipeline.fit(trainDF)
# Out:
# CPU times: user 15.3 ms, sys: 4.19 ms, total: 19.5 ms
# Wall time: 4.52 s

# %% [markdown]
# ### View the model information
#
# Print out the model coefficients and view the pValues, RMSE and R^2. We define the functions `modelInfo(inputCols, pipelineModel)` and `getEvaluationMetrics(pipelineModel,outputCol,testDF)` to report this information.

# %%
def modelInfo(inputCols, pipelineModel):
    # Create a zipped list containing the coefficients and the data
    modelCols = copy.deepcopy(inputCols)
    modelCoeffs = list(pipelineModel.stages[-1].coefficients)
    modelCoeffs.insert(0,pipelineModel.stages[-1].intercept)
    modelCols.insert(0,"intercept")
    modelZippedList = list(map(list, zip(modelCols, modelCoeffs)))
    
    # Add in the p-values
    pvals = pipelineModel.stages[-1].summary.pValues
    
    # Create the pandas DataFrame
    modelDF = pd.DataFrame(modelZippedList, columns = ['Column name', 'Coefficient'])
    modelDF['pValues'] = pvals
    return modelDF

# %%
# Calculate adjusted r2 (https://towardsdatascience.com/machine-learning-linear-regression-using-pyspark-9d5d5c772b42)
# This function will allow us to calculate the adjusted r-square value when we do PCA later. The default r-square function does not take into account k. 
def adj_r2(r2, inputCols, testDF, k = 0):
    n = testDF.count()
    if k == 0:
        p = len(inputCols)
    else: 
        p = len(inputCols) + k - 1
    
    adjusted_r2 = 1-(((1-r2)*(n-1))/(n-p-1))
    return adjusted_r2

# %%
def getEvaluationMetrics(pipelineModel,outputCol,testDF,inputCols):
    predDF = pipelineModel.transform(testDF)
    print()
    print('type preddf' + str(type(predDF)))
    print()
    predDF.select(outputCol, "prediction").show(10)
    
    print(predDF)
    
    regressionEvaluator = RegressionEvaluator(
    predictionCol="prediction",
    labelCol=outputCol,
    metricName="rmse")
    rmse = regressionEvaluator.evaluate(predDF)

    regressionEvaluator = RegressionEvaluator(
    predictionCol="prediction",
    labelCol=outputCol,
    metricName="r2")
    r2 = regressionEvaluator.evaluate(predDF)
      
    # Manually calculate Adjusted r2
    adjusted_r2 = adj_r2(r2, inputCols, testDF)
    
    return rmse, r2, adjusted_r2

# %% [markdown]
# ### Test out different combinations of features and outputs
#
# Here we test out models in order to find the best combination of features.

# %%
print("** All original inputs, original output **")
inputCols = ["total_spend","total_events","purchase_events", "total_sessions", "avg_session_length", "avg_interactions_per_session", "max_interactions_per_session",
             "purchase_pct_of_total_events", "view_pct_of_total_events", "cart_pct_of_total_events","avg_purchases_per_session", "cart_events", "view_events", 
             "sessions_with_purchase", "sessions_with_cart","sessions_with_view", "pct_sessions_end_purchase", "pct_sessions_end_cart", 'sd_session_length', 
             'sd_interactions_per_session', 'sd_purchases_per_session']


outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** All original inputs, original output **
# Model coefficients
#                      Column name  Coefficient       pValues
# 0                      intercept -3205.991128  0.000000e+00
# 1                    total_spend     4.102997  0.000000e+00
# 2                   total_events   225.554473  0.000000e+00
# 3                purchase_events -2619.098410  2.442491e-15
# 4                 total_sessions  1212.473221  3.236858e-02
# 5             avg_session_length    -0.093983  1.403162e-06
# 6   avg_interactions_per_session  -165.476869  1.663153e-07
# 7   max_interactions_per_session    97.135508  9.999787e-01
# 8   purchase_pct_of_total_events -8248.562191  9.999853e-01
# 9       view_pct_of_total_events  5662.164627  1.000000e+00
# 10      cart_pct_of_total_events -1563.829248  5.654318e-01
# 11     avg_purchases_per_session  -240.537590  4.574254e-01
# 12                   cart_events   -22.617590  0.000000e+00
# 13                   view_events  -200.201096  2.001908e-05
# 14        sessions_with_purchase  -763.284255  1.027489e-11
# 15            sessions_with_cart   769.608705  3.566036e-13
# 16            sessions_with_view -1103.848661  1.116693e-05
# 17     pct_sessions_end_purchase  3292.306583  3.854910e-04
# 18         pct_sessions_end_cart -3082.630626  1.555626e-05
# 19             sd_session_length     0.049955  6.354681e-03
# 20   sd_interactions_per_session  -116.634285  9.902797e-05
# 21      sd_purchases_per_session  1407.481147  9.999911e-01
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +-----------------+------------------+
# |    T_total_spend|        prediction|
# +-----------------+------------------+
# |              0.0| 4278.448884588216|
# |              0.0|2957.8154507649506|
# |              0.0| 3251.269554010116|
# |              0.0|1911.5530770889718|
# |              0.0| 3246.189759640157|
# |              0.0|1119.9937296904955|
# |              0.0|1328.8118104400546|
# |              0.0| 6964.132907546744|
# |79118.00024795532|146003.67060008756|
# |663.1999969482422| 7508.058988929317|
# +-----------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 43478.6
# R^2 is 0.61437
# Adjusted R^2 is 0.61426

# %% [markdown]
# ### There's likely collinearity between some of these features. Let's take a look at a correlation matrix:

# %%
#Create function to view correlation matrices
# https://stackoverflow.com/questions/52214404/how-to-get-the-correlation-matrix-of-a-pyspark-data-frame
def generateCorrMatrix(inputCols, dataframe):
    # Select input columns for Correlation Matrix & transform
    vector_col = 'corr_features'
    corrAssembler = VectorAssembler(inputCols=inputCols, outputCol=vector_col)
    df_vector = corrAssembler.transform(dataframe).select(vector_col)
    
    #get correlation matrix
    matrix = Correlation.corr(df_vector, vector_col)
    result = matrix.collect()[0]["pearson({})".format(vector_col)].values
    readable = pd.DataFrame(result.reshape(-1, len(inputCols)), columns=inputCols, index=inputCols)
    
    return readable

# %%
generateCorrMatrix(inputCols, trainDF)
# Out:
#                               total_spend  total_events  purchase_events  \
# total_spend                      1.000000      0.564621         0.481098
# total_events                     0.564621      1.000000         0.367146
# purchase_events                  0.481098      0.367146         1.000000
# total_sessions                   0.151065      0.467376         0.338770
# avg_session_length               0.043725      0.109398         0.046947
# avg_interactions_per_session    -0.004885      0.136702         0.059073
# max_interactions_per_session     0.042578      0.380164         0.173412
# purchase_pct_of_total_events     0.083175     -0.182647         0.096620
# view_pct_of_total_events        -0.087756      0.186159        -0.100247
# cart_pct_of_total_events         0.073183     -0.150776         0.082442
# avg_purchases_per_session        0.119181     -0.105877         0.226345
# cart_events                      0.338576      0.384654         0.712189
# view_events                      0.066552      0.514898         0.227308
# sessions_with_purchase           0.488184      0.387877         0.932698
# sessions_with_cart               0.403708      0.440534         0.776645
# sessions_with_view               0.148906      0.465337         0.339643
# pct_sessions_end_purchase        0.069628     -0.171989         0.087018
# pct_sessions_end_cart            0.009892      0.048450         0.013407
# sd_session_length                0.050417      0.134815         0.060594
# sd_interactions_per_session      0.019942      0.273639         0.112997
# sd_purchases_per_session         0.175506      0.089593         0.359093
#
#                               total_sessions  avg_session_length  \
# total_spend                         0.151065            0.043725
# total_events                        0.467376            0.109398
# purchase_events                     0.338770            0.046947
# total_sessions                      1.000000            0.174913
# avg_session_length                  0.174913            1.000000
# avg_interactions_per_session       -0.039855            0.025044
# max_interactions_per_session        0.394534            0.092508
# purchase_pct_of_total_events       -0.407273           -0.090967
# view_pct_of_total_events            0.412775            0.063875
# cart_pct_of_total_events           -0.332673           -0.031355
# avg_purchases_per_session          -0.387873           -0.066332
# cart_events                         0.444593            0.130374
# view_events                         0.750850            0.134185
# sessions_with_purchase              0.383884            0.053639
# sessions_with_cart                  0.577977            0.147385
# sessions_with_view                  0.996996            0.156466
# pct_sessions_end_purchase          -0.491223           -0.090676
# pct_sessions_end_cart               0.090440            0.053622
# sd_session_length                   0.229781            0.948501
# sd_interactions_per_session         0.242894            0.059240
# sd_purchases_per_session           -0.000881           -0.009554
#
#                               avg_interactions_per_session  \
# total_spend                                      -0.004885
# total_events                                      0.136702
# purchase_events                                   0.059073
# total_sessions                                   -0.039855
# avg_session_length                                0.025044
# avg_interactions_per_session                      1.000000
# max_interactions_per_session                      0.637865
# purchase_pct_of_total_events                     -0.277896
# view_pct_of_total_events                          0.228600
# cart_pct_of_total_events                         -0.146542
# avg_purchases_per_session                         0.251451
# cart_events                                       0.151535
# view_events                                       0.304647
# sessions_with_purchase                           -0.000782
# sessions_with_cart                               -0.009603
# sessions_with_view                               -0.036020
# pct_sessions_end_purchase                         0.121906
# pct_sessions_end_cart                            -0.014604
# sd_session_length                                -0.009738
# sd_interactions_per_session                       0.550659
# sd_purchases_per_session                          0.041945
#
#                               max_interactions_per_session  \
# total_spend                                       0.042578
# total_events                                      0.380164
# purchase_events                                   0.173412
# total_sessions                                    0.394534
# avg_session_length                                0.092508
# avg_interactions_per_session                      0.637865
# max_interactions_per_session                      1.000000
# purchase_pct_of_total_events                     -0.464993
# view_pct_of_total_events                          0.456032
# cart_pct_of_total_events                         -0.356704
# avg_purchases_per_session                        -0.176445
# cart_events                                       0.322928
# view_events                                       0.737453
# sessions_with_purchase                            0.140828
# sessions_with_cart                                0.229791
# sessions_with_view                                0.397881
# pct_sessions_end_purchase                        -0.315549
# pct_sessions_end_cart                             0.055000
# sd_session_length                                 0.092205
# sd_interactions_per_session                       0.876179
# sd_purchases_per_session                          0.124785
#
#                               purchase_pct_of_total_events  \
# total_spend                                       0.083175
# total_events                                     -0.182647
# purchase_events                                   0.096620
# total_sessions                                   -0.407273
# avg_session_length                               -0.090967
# avg_interactions_per_session                     -0.277896
# max_interactions_per_session                     -0.464993
# purchase_pct_of_total_events                      1.000000
# view_pct_of_total_events                         -0.832517
# cart_pct_of_total_events                          0.542351
# avg_purchases_per_session                         0.662773
# cart_events                                      -0.146767
# view_events                                      -0.420846
# sessions_with_purchase                            0.074052
# sessions_with_cart                               -0.119763
# sessions_with_view                               -0.408404
# pct_sessions_end_purchase                         0.767058
# pct_sessions_end_cart                            -0.253101
# sd_session_length                                -0.090528
# sd_interactions_per_session                      -0.478889
# sd_purchases_per_session                         -0.130114
#
#                               view_pct_of_total_events  \
# total_spend                                  -0.087756
# total_events                                  0.186159
# purchase_events                              -0.100247
# total_sessions                                0.412775
# avg_session_length                            0.063875
# avg_interactions_per_session                  0.228600
# max_interactions_per_session                  0.456032
# purchase_pct_of_total_events                 -0.832517
# view_pct_of_total_events                      1.000000
# cart_pct_of_total_events                     -0.916960
# avg_purchases_per_session                    -0.621138
# cart_events                                  -0.083772
# view_events                                   0.461413
# sessions_with_purchase                       -0.082660
# sessions_with_cart                            0.015405
# sessions_with_view                            0.419957
# pct_sessions_end_purchase                    -0.721475
# pct_sessions_end_cart                        -0.019379
# sd_session_length                             0.067755
# sd_interactions_per_session                   0.460357
# sd_purchases_per_session                      0.082648
#
#                               cart_pct_of_total_events  ...  cart_events  \
# total_spend                                   0.073183  ...     0.338576
# total_events                                 -0.150776  ...     0.384654
# purchase_events                               0.082442  ...     0.712189
# total_sessions                               -0.332673  ...     0.444593
# avg_session_length                           -0.031355  ...     0.130374
# avg_interactions_per_session                 -0.146542  ...     0.151535
# max_interactions_per_session                 -0.356704  ...     0.322928
# purchase_pct_of_total_events                  0.542351  ...    -0.146767
# view_pct_of_total_events                     -0.916960  ...    -0.083772
# cart_pct_of_total_events                      1.000000  ...     0.232741
# avg_purchases_per_session                     0.464654  ...     0.011576
# cart_events                                   0.232741  ...     1.000000
# view_events                                  -0.396659  ...     0.339420
# sessions_with_purchase                        0.072024  ...     0.686561
# sessions_with_cart                            0.062888  ...     0.806203
# sessions_with_view                           -0.342749  ...     0.433541
# pct_sessions_end_purchase                     0.541713  ...    -0.106843
# pct_sessions_end_cart                         0.211667  ...     0.284537
# sd_session_length                            -0.037556  ...     0.150338
# sd_interactions_per_session                  -0.353255  ...     0.249299
# sd_purchases_per_session                     -0.031631  ...     0.251052
#
#                               view_events  sessions_with_purchase  \
# total_spend                      0.066552                0.488184
# total_events                     0.514898                0.387877
# purchase_events                  0.227308                0.932698
# total_sessions                   0.750850                0.383884
# avg_session_length               0.134185                0.053639
# avg_interactions_per_session     0.304647               -0.000782
# max_interactions_per_session     0.737453                0.140828
# purchase_pct_of_total_events    -0.420846                0.074052
# view_pct_of_total_events         0.461413               -0.082660
# cart_pct_of_total_events        -0.396659                0.072024
# avg_purchases_per_session       -0.304312                0.112621
# cart_events                      0.339420                0.686561
# view_events                      1.000000                0.235664
# sessions_with_purchase           0.235664                1.000000
# sessions_with_cart               0.393132                0.841435
# sessions_with_view               0.755356                0.384296
# pct_sessions_end_purchase       -0.400806                0.078945
# pct_sessions_end_cart            0.050192                0.018408
# sd_session_length                0.168932                0.070994
# sd_interactions_per_session      0.547943                0.078154
# sd_purchases_per_session         0.002269                0.219623
#
#                               sessions_with_cart  sessions_with_view  \
# total_spend                             0.403708            0.148906
# total_events                            0.440534            0.465337
# purchase_events                         0.776645            0.339643
# total_sessions                          0.577977            0.996996
# avg_session_length                      0.147385            0.156466
# avg_interactions_per_session           -0.009603           -0.036020
# max_interactions_per_session            0.229791            0.397881
# purchase_pct_of_total_events           -0.119763           -0.408404
# view_pct_of_total_events                0.015405            0.419957
# cart_pct_of_total_events                0.062888           -0.342749
# avg_purchases_per_session              -0.076803           -0.386700
# cart_events                             0.806203            0.433541
# view_events                             0.393132            0.755356
# sessions_with_purchase                  0.841435            0.384296
# sessions_with_cart                      1.000000            0.560858
# sessions_with_view                      0.560858            1.000000
# pct_sessions_end_purchase              -0.141802           -0.490059
# pct_sessions_end_cart                   0.348739            0.077848
# sd_session_length                       0.183833            0.208555
# sd_interactions_per_session             0.137613            0.246006
# sd_purchases_per_session                0.177546            0.000465
#
#                               pct_sessions_end_purchase  \
# total_spend                                    0.069628
# total_events                                  -0.171989
# purchase_events                                0.087018
# total_sessions                                -0.491223
# avg_session_length                            -0.090676
# avg_interactions_per_session                   0.121906
# max_interactions_per_session                  -0.315549
# purchase_pct_of_total_events                   0.767058
# view_pct_of_total_events                      -0.721475
# cart_pct_of_total_events                       0.541713
# avg_purchases_per_session                      0.829093
# cart_events                                   -0.106843
# view_events                                   -0.400806
# sessions_with_purchase                         0.078945
# sessions_with_cart                            -0.141802
# sessions_with_view                            -0.490059
# pct_sessions_end_purchase                      1.000000
# pct_sessions_end_cart                         -0.301206
# sd_session_length                             -0.107775
# sd_interactions_per_session                   -0.393234
# sd_purchases_per_session                      -0.303561
#
#                               pct_sessions_end_cart  sd_session_length  \
# total_spend                                0.009892           0.050417
# total_events                               0.048450           0.134815
# purchase_events                            0.013407           0.060594
# total_sessions                             0.090440           0.229781
# avg_session_length                         0.053622           0.948501
# avg_interactions_per_session              -0.014604          -0.009738
# max_interactions_per_session               0.055000           0.092205
# purchase_pct_of_total_events              -0.253101          -0.090528
# view_pct_of_total_events                  -0.019379           0.067755
# cart_pct_of_total_events                   0.211667          -0.037556
# avg_purchases_per_session                 -0.244417          -0.085614
# cart_events                                0.284537           0.150338
# view_events                                0.050192           0.168932
# sessions_with_purchase                     0.018408           0.070994
# sessions_with_cart                         0.348739           0.183833
# sessions_with_view                         0.077848           0.208555
# pct_sessions_end_purchase                 -0.301206          -0.107775
# pct_sessions_end_cart                      1.000000           0.056476
# sd_session_length                          0.056476           1.000000
# sd_interactions_per_session                0.084980           0.052994
# sd_purchases_per_session                   0.202615          -0.013750
#
#                               sd_interactions_per_session  \
# total_spend                                      0.019942
# total_events                                     0.273639
# purchase_events                                  0.112997
# total_sessions                                   0.242894
# avg_session_length                               0.059240
# avg_interactions_per_session                     0.550659
# max_interactions_per_session                     0.876179
# purchase_pct_of_total_events                    -0.478889
# view_pct_of_total_events                         0.460357
# cart_pct_of_total_events                        -0.353255
# avg_purchases_per_session                       -0.256859
# cart_events                                      0.249299
# view_events                                      0.547943
# sessions_with_purchase                           0.078154
# sessions_with_cart                               0.137613
# sessions_with_view                               0.246006
# pct_sessions_end_purchase                       -0.393234
# pct_sessions_end_cart                            0.084980
# sd_session_length                                0.052994
# sd_interactions_per_session                      1.000000
# sd_purchases_per_session                         0.318185
#
#                               sd_purchases_per_session
# total_spend                                   0.175506
# total_events                                  0.089593
# purchase_events                               0.359093
# total_sessions                               -0.000881
# avg_session_length                           -0.009554
# avg_interactions_per_session                  0.041945
# max_interactions_per_session                  0.124785
# purchase_pct_of_total_events                 -0.130114
# view_pct_of_total_events                      0.082648
# cart_pct_of_total_events                     -0.031631
# avg_purchases_per_session                    -0.027285
# cart_events                                   0.251052
# view_events                                   0.002269
# sessions_with_purchase                        0.219623
# sessions_with_cart                            0.177546
# sessions_with_view                            0.000465
# pct_sessions_end_purchase                    -0.303561
# pct_sessions_end_cart                         0.202615
# sd_session_length                            -0.013750
# sd_interactions_per_session                   0.318185
# sd_purchases_per_session                      1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# #### There's a lot of very correlated features in there! We took care of that in an iterative manner while looking at p-values to ensure we pick the best features to keep. The adjusted r^2 of the model below is nearly as good as the model above, with only 4 features!

# %%
# Redo, iteratively removing & adding features to find the best combination. In the real world, 
# sacraficing a fraction of a percent of performance to dramatically reduce the number of features can be very useful. 
# Intermediate stages not shown because this was all done in the same cell. 
print("** Best original inputs, original output **")
inputCols = ["total_spend","total_events","purchase_events", "view_events"]

             
             #"purchase_events" causes this to break for some reason? won't generate p-values when it's included with eveyrthing else
outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** Best original inputs, original output **
# Model coefficients
#        Column name  Coefficient  pValues
# 0        intercept  1313.218380      0.0
# 1      total_spend     4.088648      0.0
# 2     total_events   227.102068      0.0
# 3  purchase_events -2556.784673      0.0
# 4      view_events  -166.467129      0.0
# +-----------------+------------------+
# |    T_total_spend|        prediction|
# +-----------------+------------------+
# |              0.0| 3968.343537712809|
# |              0.0|  3155.42960828224|
# |              0.0|1088.1524167513835|
# |              0.0| 813.7975938765567|
# |              0.0| 2406.689900135093|
# |              0.0| 158.3496209132586|
# |              0.0| 1540.409627549518|
# |              0.0|  6403.87690864553|
# |79118.00024795532|143457.33819014102|
# |663.1999969482422| 6457.116320074398|
# +-----------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 43535.3
# R^2 is 0.61337
# Adjusted R^2 is 0.61334

# %%
# This final feature set has an adjusted r-square that is nearly as good and has dramatically reduced the number of coefficients.

# %%
print("** Original + Log-transformed inputs, normal output **")
inputCols = ["total_spend","total_events", "total_sessions", "avg_session_length", "avg_interactions_per_session", "max_interactions_per_session",
             "purchase_pct_of_total_events", "view_pct_of_total_events", "cart_pct_of_total_events","avg_purchases_per_session", "cart_events", "purchase_events",
             "view_events", "sessions_with_purchase", "sessions_with_cart","sessions_with_view", "pct_sessions_end_purchase", "pct_sessions_end_cart", 'sd_session_length', 
             'sd_interactions_per_session', 'sd_purchases_per_session', "total_spend_log", "total_events_log", "purchase_events_log", "total_sessions_log"]
outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** Original + Log-transformed inputs, normal output **
# Model coefficients
#                      Column name   Coefficient       pValues
# 0                      intercept  64676.487526  0.000000e+00
# 1                    total_spend      3.969448  0.000000e+00
# 2                   total_events    221.150198  0.000000e+00
# 3                 total_sessions   1479.276643  2.195719e-02
# 4             avg_session_length     -0.100486  1.302602e-11
# 5   avg_interactions_per_session   -243.069177  2.713388e-06
# 6   max_interactions_per_session     88.190723  9.998417e-01
# 7   purchase_pct_of_total_events -61705.024243  9.998736e-01
# 8       view_pct_of_total_events -49266.125091  9.998530e-01
# 9       cart_pct_of_total_events -57300.531692  0.000000e+00
# 10     avg_purchases_per_session  -4571.156833  1.591293e-01
# 11                   cart_events    -42.840964  0.000000e+00
# 12               purchase_events  -2008.129461  0.000000e+00
# 13                   view_events   -196.392595  0.000000e+00
# 14        sessions_with_purchase  -2120.616004  6.256995e-12
# 15            sessions_with_cart    777.641193  2.997602e-14
# 16            sessions_with_view  -1151.895787  0.000000e+00
# 17     pct_sessions_end_purchase -14642.002611  2.688123e-05
# 18         pct_sessions_end_cart  -3652.926123  4.676921e-06
# 19             sd_session_length      0.052860  5.831668e-02
# 20   sd_interactions_per_session    -81.748424  0.000000e+00
# 21      sd_purchases_per_session  -6260.882170  0.000000e+00
# 22               total_spend_log   1456.906364  4.516276e-10
# 23              total_events_log   1249.068723  0.000000e+00
# 24           purchase_events_log   8170.852609  0.000000e+00
# 25            total_sessions_log -10011.478226  9.998340e-01
# +-----------------+-------------------+
# |    T_total_spend|         prediction|
# +-----------------+-------------------+
# |              0.0|  6885.351047502663|
# |              0.0|  4928.145300082018|
# |              0.0|  5190.450125859177|
# |              0.0| -2477.744147859499|
# |              0.0|-352.56229783392337|
# |              0.0|-3259.2474228700885|
# |              0.0| 2351.4713360536625|
# |              0.0|  8715.269676963493|
# |79118.00024795532| 146048.40901718964|
# |663.1999969482422|  7569.856075209063|
# +-----------------+-------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 43389.1
# R^2 is 0.61596
# Adjusted R^2 is 0.61582

# %%
generateCorrMatrix(inputCols, trainDF)
# Out:
#                               total_spend  total_events  total_sessions  \
# total_spend                      1.000000      0.564621        0.151065
# total_events                     0.564621      1.000000        0.467376
# total_sessions                   0.151065      0.467376        1.000000
# avg_session_length               0.043725      0.109398        0.174913
# avg_interactions_per_session    -0.004885      0.136702       -0.039855
# max_interactions_per_session     0.042578      0.380164        0.394534
# purchase_pct_of_total_events     0.083175     -0.182647       -0.407273
# view_pct_of_total_events        -0.087756      0.186159        0.412775
# cart_pct_of_total_events         0.073183     -0.150776       -0.332673
# avg_purchases_per_session        0.119181     -0.105877       -0.387873
# cart_events                      0.338576      0.384654        0.444593
# purchase_events                  0.481098      0.367146        0.338770
# view_events                      0.066552      0.514898        0.750850
# sessions_with_purchase           0.488184      0.387877        0.383884
# sessions_with_cart               0.403708      0.440534        0.577977
# sessions_with_view               0.148906      0.465337        0.996996
# pct_sessions_end_purchase        0.069628     -0.171989       -0.491223
# pct_sessions_end_cart            0.009892      0.048450        0.090440
# sd_session_length                0.050417      0.134815        0.229781
# sd_interactions_per_session      0.019942      0.273639        0.242894
# sd_purchases_per_session         0.175506      0.089593       -0.000881
# total_spend_log                  0.536203      0.350289        0.116135
# total_events_log                 0.379234      0.644777        0.635677
# purchase_events_log              0.441939      0.361981        0.319133
# total_sessions_log               0.165674      0.405858        0.793039
#
#                               avg_session_length  \
# total_spend                             0.043725
# total_events                            0.109398
# total_sessions                          0.174913
# avg_session_length                      1.000000
# avg_interactions_per_session            0.025044
# max_interactions_per_session            0.092508
# purchase_pct_of_total_events           -0.090967
# view_pct_of_total_events                0.063875
# cart_pct_of_total_events               -0.031355
# avg_purchases_per_session              -0.066332
# cart_events                             0.130374
# purchase_events                         0.046947
# view_events                             0.134185
# sessions_with_purchase                  0.053639
# sessions_with_cart                      0.147385
# sessions_with_view                      0.156466
# pct_sessions_end_purchase              -0.090676
# pct_sessions_end_cart                   0.053622
# sd_session_length                       0.948501
# sd_interactions_per_session             0.059240
# sd_purchases_per_session               -0.009554
# total_spend_log                         0.026239
# total_events_log                        0.136689
# purchase_events_log                     0.053213
# total_sessions_log                      0.146432
#
#                               avg_interactions_per_session  \
# total_spend                                      -0.004885
# total_events                                      0.136702
# total_sessions                                   -0.039855
# avg_session_length                                0.025044
# avg_interactions_per_session                      1.000000
# max_interactions_per_session                      0.637865
# purchase_pct_of_total_events                     -0.277896
# view_pct_of_total_events                          0.228600
# cart_pct_of_total_events                         -0.146542
# avg_purchases_per_session                         0.251451
# cart_events                                       0.151535
# purchase_events                                   0.059073
# view_events                                       0.304647
# sessions_with_purchase                           -0.000782
# sessions_with_cart                               -0.009603
# sessions_with_view                               -0.036020
# pct_sessions_end_purchase                         0.121906
# pct_sessions_end_cart                            -0.014604
# sd_session_length                                -0.009738
# sd_interactions_per_session                       0.550659
# sd_purchases_per_session                          0.041945
# total_spend_log                                  -0.019712
# total_events_log                                  0.295554
# purchase_events_log                               0.085442
# total_sessions_log                               -0.089399
#
#                               max_interactions_per_session  \
# total_spend                                       0.042578
# total_events                                      0.380164
# total_sessions                                    0.394534
# avg_session_length                                0.092508
# avg_interactions_per_session                      0.637865
# max_interactions_per_session                      1.000000
# purchase_pct_of_total_events                     -0.464993
# view_pct_of_total_events                          0.456032
# cart_pct_of_total_events                         -0.356704
# avg_purchases_per_session                        -0.176445
# cart_events                                       0.322928
# purchase_events                                   0.173412
# view_events                                       0.737453
# sessions_with_purchase                            0.140828
# sessions_with_cart                                0.229791
# sessions_with_view                                0.397881
# pct_sessions_end_purchase                        -0.315549
# pct_sessions_end_cart                             0.055000
# sd_session_length                                 0.092205
# sd_interactions_per_session                       0.876179
# sd_purchases_per_session                          0.124785
# total_spend_log                                   0.007458
# total_events_log                                  0.608817
# purchase_events_log                               0.201523
# total_sessions_log                                0.426848
#
#                               purchase_pct_of_total_events  \
# total_spend                                       0.083175
# total_events                                     -0.182647
# total_sessions                                   -0.407273
# avg_session_length                               -0.090967
# avg_interactions_per_session                     -0.277896
# max_interactions_per_session                     -0.464993
# purchase_pct_of_total_events                      1.000000
# view_pct_of_total_events                         -0.832517
# cart_pct_of_total_events                          0.542351
# avg_purchases_per_session                         0.662773
# cart_events                                      -0.146767
# purchase_events                                   0.096620
# view_events                                      -0.420846
# sessions_with_purchase                            0.074052
# sessions_with_cart                               -0.119763
# sessions_with_view                               -0.408404
# pct_sessions_end_purchase                         0.767058
# pct_sessions_end_cart                            -0.253101
# sd_session_length                                -0.090528
# sd_interactions_per_session                      -0.478889
# sd_purchases_per_session                         -0.130114
# total_spend_log                                   0.186874
# total_events_log                                 -0.617351
# purchase_events_log                               0.109589
# total_sessions_log                               -0.630544
#
#                               view_pct_of_total_events  \
# total_spend                                  -0.087756
# total_events                                  0.186159
# total_sessions                                0.412775
# avg_session_length                            0.063875
# avg_interactions_per_session                  0.228600
# max_interactions_per_session                  0.456032
# purchase_pct_of_total_events                 -0.832517
# view_pct_of_total_events                      1.000000
# cart_pct_of_total_events                     -0.916960
# avg_purchases_per_session                    -0.621138
# cart_events                                  -0.083772
# purchase_events                              -0.100247
# view_events                                   0.461413
# sessions_with_purchase                       -0.082660
# sessions_with_cart                            0.015405
# sessions_with_view                            0.419957
# pct_sessions_end_purchase                    -0.721475
# pct_sessions_end_cart                        -0.019379
# sd_session_length                             0.067755
# sd_interactions_per_session                   0.460357
# sd_purchases_per_session                      0.082648
# total_spend_log                              -0.203440
# total_events_log                              0.562550
# purchase_events_log                          -0.119874
# total_sessions_log                            0.604896
#
#                               cart_pct_of_total_events  \
# total_spend                                   0.073183
# total_events                                 -0.150776
# total_sessions                               -0.332673
# avg_session_length                           -0.031355
# avg_interactions_per_session                 -0.146542
# max_interactions_per_session                 -0.356704
# purchase_pct_of_total_events                  0.542351
# view_pct_of_total_events                     -0.916960
# cart_pct_of_total_events                      1.000000
# avg_purchases_per_session                     0.464654
# cart_events                                   0.232741
# purchase_events                               0.082442
# view_events                                  -0.396659
# sessions_with_purchase                        0.072024
# sessions_with_cart                            0.062888
# sessions_with_view                           -0.342749
# pct_sessions_end_purchase                     0.541713
# pct_sessions_end_cart                         0.211667
# sd_session_length                            -0.037556
# sd_interactions_per_session                  -0.353255
# sd_purchases_per_session                     -0.031631
# total_spend_log                               0.173938
# total_events_log                             -0.408516
# purchase_events_log                           0.102868
# total_sessions_log                           -0.463234
#
#                               avg_purchases_per_session  ...  \
# total_spend                                    0.119181  ...
# total_events                                  -0.105877  ...
# total_sessions                                -0.387873  ...
# avg_session_length                            -0.066332  ...
# avg_interactions_per_session                   0.251451  ...
# max_interactions_per_session                  -0.176445  ...
# purchase_pct_of_total_events                   0.662773  ...
# view_pct_of_total_events                      -0.621138  ...
# cart_pct_of_total_events                       0.464654  ...
# avg_purchases_per_session                      1.000000  ...
# cart_events                                    0.011576  ...
# purchase_events                                0.226345  ...
# view_events                                   -0.304312  ...
# sessions_with_purchase                         0.112621  ...
# sessions_with_cart                            -0.076803  ...
# sessions_with_view                            -0.386700  ...
# pct_sessions_end_purchase                      0.829093  ...
# pct_sessions_end_cart                         -0.244417  ...
# sd_session_length                             -0.085614  ...
# sd_interactions_per_session                   -0.256859  ...
# sd_purchases_per_session                      -0.027285  ...
# total_spend_log                                0.242444  ...
# total_events_log                              -0.351623  ...
# purchase_events_log                            0.285990  ...
# total_sessions_log                            -0.630276  ...
#
#                               sessions_with_view  pct_sessions_end_purchase  \
# total_spend                             0.148906                   0.069628
# total_events                            0.465337                  -0.171989
# total_sessions                          0.996996                  -0.491223
# avg_session_length                      0.156466                  -0.090676
# avg_interactions_per_session           -0.036020                   0.121906
# max_interactions_per_session            0.397881                  -0.315549
# purchase_pct_of_total_events           -0.408404                   0.767058
# view_pct_of_total_events                0.419957                  -0.721475
# cart_pct_of_total_events               -0.342749                   0.541713
# avg_purchases_per_session              -0.386700                   0.829093
# cart_events                             0.433541                  -0.106843
# purchase_events                         0.339643                   0.087018
# view_events                             0.755356                  -0.400806
# sessions_with_purchase                  0.384296                   0.078945
# sessions_with_cart                      0.560858                  -0.141802
# sessions_with_view                      1.000000                  -0.490059
# pct_sessions_end_purchase              -0.490059                   1.000000
# pct_sessions_end_cart                   0.077848                  -0.301206
# sd_session_length                       0.208555                  -0.107775
# sd_interactions_per_session             0.246006                  -0.393234
# sd_purchases_per_session                0.000465                  -0.303561
# total_spend_log                         0.114192                   0.166302
# total_events_log                        0.635342                  -0.537190
# purchase_events_log                     0.319422                   0.098038
# total_sessions_log                      0.791114                  -0.794328
#
#                               pct_sessions_end_cart  sd_session_length  \
# total_spend                                0.009892           0.050417
# total_events                               0.048450           0.134815
# total_sessions                             0.090440           0.229781
# avg_session_length                         0.053622           0.948501
# avg_interactions_per_session              -0.014604          -0.009738
# max_interactions_per_session               0.055000           0.092205
# purchase_pct_of_total_events              -0.253101          -0.090528
# view_pct_of_total_events                  -0.019379           0.067755
# cart_pct_of_total_events                   0.211667          -0.037556
# avg_purchases_per_session                 -0.244417          -0.085614
# cart_events                                0.284537           0.150338
# purchase_events                            0.013407           0.060594
# view_events                                0.050192           0.168932
# sessions_with_purchase                     0.018408           0.070994
# sessions_with_cart                         0.348739           0.183833
# sessions_with_view                         0.077848           0.208555
# pct_sessions_end_purchase                 -0.301206          -0.107775
# pct_sessions_end_cart                      1.000000           0.056476
# sd_session_length                          0.056476           1.000000
# sd_interactions_per_session                0.084980           0.052994
# sd_purchases_per_session                   0.202615          -0.013750
# total_spend_log                            0.001625           0.031988
# total_events_log                           0.177961           0.152525
# purchase_events_log                        0.024858           0.063484
# total_sessions_log                         0.217211           0.179634
#
#                               sd_interactions_per_session  \
# total_spend                                      0.019942
# total_events                                     0.273639
# total_sessions                                   0.242894
# avg_session_length                               0.059240
# avg_interactions_per_session                     0.550659
# max_interactions_per_session                     0.876179
# purchase_pct_of_total_events                    -0.478889
# view_pct_of_total_events                         0.460357
# cart_pct_of_total_events                        -0.353255
# avg_purchases_per_session                       -0.256859
# cart_events                                      0.249299
# purchase_events                                  0.112997
# view_events                                      0.547943
# sessions_with_purchase                           0.078154
# sessions_with_cart                               0.137613
# sessions_with_view                               0.246006
# pct_sessions_end_purchase                       -0.393234
# pct_sessions_end_cart                            0.084980
# sd_session_length                                0.052994
# sd_interactions_per_session                      1.000000
# sd_purchases_per_session                         0.318185
# total_spend_log                                 -0.017703
# total_events_log                                 0.546454
# purchase_events_log                              0.153056
# total_sessions_log                               0.385859
#
#                               sd_purchases_per_session  total_spend_log  \
# total_spend                                   0.175506         0.536203
# total_events                                  0.089593         0.350289
# total_sessions                               -0.000881         0.116135
# avg_session_length                           -0.009554         0.026239
# avg_interactions_per_session                  0.041945        -0.019712
# max_interactions_per_session                  0.124785         0.007458
# purchase_pct_of_total_events                 -0.130114         0.186874
# view_pct_of_total_events                      0.082648        -0.203440
# cart_pct_of_total_events                     -0.031631         0.173938
# avg_purchases_per_session                    -0.027285         0.242444
# cart_events                                   0.251052         0.334059
# purchase_events                               0.359093         0.464972
# view_events                                   0.002269         0.030189
# sessions_with_purchase                        0.219623         0.475812
# sessions_with_cart                            0.177546         0.386792
# sessions_with_view                            0.000465         0.114192
# pct_sessions_end_purchase                    -0.303561         0.166302
# pct_sessions_end_cart                         0.202615         0.001625
# sd_session_length                            -0.013750         0.031988
# sd_interactions_per_session                   0.318185        -0.017703
# sd_purchases_per_session                      1.000000         0.229082
# total_spend_log                               0.229082         1.000000
# total_events_log                              0.233302         0.334137
# purchase_events_log                           0.426708         0.599833
# total_sessions_log                            0.215818         0.134090
#
#                               total_events_log  purchase_events_log  \
# total_spend                           0.379234             0.441939
# total_events                          0.644777             0.361981
# total_sessions                        0.635677             0.319133
# avg_session_length                    0.136689             0.053213
# avg_interactions_per_session          0.295554             0.085442
# max_interactions_per_session          0.608817             0.201523
# purchase_pct_of_total_events         -0.617351             0.109589
# view_pct_of_total_events              0.562550            -0.119874
# cart_pct_of_total_events             -0.408516             0.102868
# avg_purchases_per_session            -0.351623             0.285990
# cart_events                           0.481563             0.603448
# purchase_events                       0.381236             0.793098
# view_events                           0.637956             0.222389
# sessions_with_purchase                0.405391             0.790096
# sessions_with_cart                    0.525724             0.677326
# sessions_with_view                    0.635342             0.319422
# pct_sessions_end_purchase            -0.537190             0.098038
# pct_sessions_end_cart                 0.177961             0.024858
# sd_session_length                     0.152525             0.063484
# sd_interactions_per_session           0.546454             0.153056
# sd_purchases_per_session              0.233302             0.426708
# total_spend_log                       0.334137             0.599833
# total_events_log                      1.000000             0.481189
# purchase_events_log                   0.481189             1.000000
# total_sessions_log                    0.790438             0.384584
#
#                               total_sessions_log
# total_spend                             0.165674
# total_events                            0.405858
# total_sessions                          0.793039
# avg_session_length                      0.146432
# avg_interactions_per_session           -0.089399
# max_interactions_per_session            0.426848
# purchase_pct_of_total_events           -0.630544
# view_pct_of_total_events                0.604896
# cart_pct_of_total_events               -0.463234
# avg_purchases_per_session              -0.630276
# cart_events                             0.428794
# purchase_events                         0.317658
# view_events                             0.617183
# sessions_with_purchase                  0.367441
# sessions_with_cart                      0.544338
# sessions_with_view                      0.791114
# pct_sessions_end_purchase              -0.794328
# pct_sessions_end_cart                   0.217211
# sd_session_length                       0.179634
# sd_interactions_per_session             0.385859
# sd_purchases_per_session                0.215818
# total_spend_log                         0.134090
# total_events_log                        0.790438
# purchase_events_log                     0.384584
# total_sessions_log                      1.000000
#
# [25 rows x 25 columns]

# %%
# Again, we iteratively tested features to find the best smaller set. 

print("** Smaller Original + Log-transformed inputs, normal output **")
inputCols = ["total_spend","total_events", "avg_session_length", "max_interactions_per_session", 
              "cart_pct_of_total_events","avg_purchases_per_session",  "purchase_events", 'sd_purchases_per_session',
              "view_events", "sessions_with_purchase", "sessions_with_view", "pct_sessions_end_purchase", "pct_sessions_end_cart", 'sd_session_length', 
            "total_spend_log","total_events_log", "purchase_events_log", "total_sessions_log"]
outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** Smaller Original + Log-transformed inputs, normal output **
# Model coefficients
#                      Column name   Coefficient       pValues
# 0                      intercept  11901.046535  0.000000e+00
# 1                    total_spend      3.958880  0.000000e+00
# 2                   total_events    222.124485  3.457475e-05
# 3             avg_session_length     -0.180450  5.185470e-02
# 4   max_interactions_per_session     20.193832  9.076295e-12
# 5       cart_pct_of_total_events  -6907.426805  0.000000e+00
# 6      avg_purchases_per_session  -5080.676490  0.000000e+00
# 7                purchase_events  -1970.098478  0.000000e+00
# 8       sd_purchases_per_session  -6956.063457  0.000000e+00
# 9                    view_events   -196.872666  0.000000e+00
# 10        sessions_with_purchase  -1476.328092  0.000000e+00
# 11            sessions_with_view    350.738617  0.000000e+00
# 12     pct_sessions_end_purchase -14673.353940  3.778907e-02
# 13         pct_sessions_end_cart   1367.757411  3.774758e-15
# 14             sd_session_length      0.089151  0.000000e+00
# 15               total_spend_log   1483.986540  1.302847e-11
# 16              total_events_log   1111.159681  0.000000e+00
# 17           purchase_events_log   7648.733758  0.000000e+00
# 18            total_sessions_log  -8491.635874  0.000000e+00
# +-----------------+-------------------+
# |    T_total_spend|         prediction|
# +-----------------+-------------------+
# |              0.0|  6876.646366294913|
# |              0.0|  5129.841834650582|
# |              0.0|  4299.575041842618|
# |              0.0| -2115.039013369089|
# |              0.0|-183.21657462714575|
# |              0.0|-2950.9297876951096|
# |              0.0| 2753.4839597345544|
# |              0.0|    9183.9297686331|
# |79118.00024795532|  142953.1032013508|
# |663.1999969482422|  7680.157808446413|
# +-----------------+-------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 43371.3
# R^2 is 0.61627
# Adjusted R^2 is 0.61617

# %%
generateCorrMatrix(inputCols, trainDF)
# Out:
#                               total_spend  total_events  avg_session_length  \
# total_spend                      1.000000      0.564621            0.043725
# total_events                     0.564621      1.000000            0.109398
# avg_session_length               0.043725      0.109398            1.000000
# max_interactions_per_session     0.042578      0.380164            0.092508
# cart_pct_of_total_events         0.073183     -0.150776           -0.031355
# avg_purchases_per_session        0.119181     -0.105877           -0.066332
# purchase_events                  0.481098      0.367146            0.046947
# sd_purchases_per_session         0.175506      0.089593           -0.009554
# view_events                      0.066552      0.514898            0.134185
# sessions_with_purchase           0.488184      0.387877            0.053639
# sessions_with_view               0.148906      0.465337            0.156466
# pct_sessions_end_purchase        0.069628     -0.171989           -0.090676
# pct_sessions_end_cart            0.009892      0.048450            0.053622
# sd_session_length                0.050417      0.134815            0.948501
# total_spend_log                  0.536203      0.350289            0.026239
# total_events_log                 0.379234      0.644777            0.136689
# purchase_events_log              0.441939      0.361981            0.053213
# total_sessions_log               0.165674      0.405858            0.146432
#
#                               max_interactions_per_session  \
# total_spend                                       0.042578
# total_events                                      0.380164
# avg_session_length                                0.092508
# max_interactions_per_session                      1.000000
# cart_pct_of_total_events                         -0.356704
# avg_purchases_per_session                        -0.176445
# purchase_events                                   0.173412
# sd_purchases_per_session                          0.124785
# view_events                                       0.737453
# sessions_with_purchase                            0.140828
# sessions_with_view                                0.397881
# pct_sessions_end_purchase                        -0.315549
# pct_sessions_end_cart                             0.055000
# sd_session_length                                 0.092205
# total_spend_log                                   0.007458
# total_events_log                                  0.608817
# purchase_events_log                               0.201523
# total_sessions_log                                0.426848
#
#                               cart_pct_of_total_events  \
# total_spend                                   0.073183
# total_events                                 -0.150776
# avg_session_length                           -0.031355
# max_interactions_per_session                 -0.356704
# cart_pct_of_total_events                      1.000000
# avg_purchases_per_session                     0.464654
# purchase_events                               0.082442
# sd_purchases_per_session                     -0.031631
# view_events                                  -0.396659
# sessions_with_purchase                        0.072024
# sessions_with_view                           -0.342749
# pct_sessions_end_purchase                     0.541713
# pct_sessions_end_cart                         0.211667
# sd_session_length                            -0.037556
# total_spend_log                               0.173938
# total_events_log                             -0.408516
# purchase_events_log                           0.102868
# total_sessions_log                           -0.463234
#
#                               avg_purchases_per_session  purchase_events  \
# total_spend                                    0.119181         0.481098
# total_events                                  -0.105877         0.367146
# avg_session_length                            -0.066332         0.046947
# max_interactions_per_session                  -0.176445         0.173412
# cart_pct_of_total_events                       0.464654         0.082442
# avg_purchases_per_session                      1.000000         0.226345
# purchase_events                                0.226345         1.000000
# sd_purchases_per_session                      -0.027285         0.359093
# view_events                                   -0.304312         0.227308
# sessions_with_purchase                         0.112621         0.932698
# sessions_with_view                            -0.386700         0.339643
# pct_sessions_end_purchase                      0.829093         0.087018
# pct_sessions_end_cart                         -0.244417         0.013407
# sd_session_length                             -0.085614         0.060594
# total_spend_log                                0.242444         0.464972
# total_events_log                              -0.351623         0.381236
# purchase_events_log                            0.285990         0.793098
# total_sessions_log                            -0.630276         0.317658
#
#                               sd_purchases_per_session  view_events  \
# total_spend                                   0.175506     0.066552
# total_events                                  0.089593     0.514898
# avg_session_length                           -0.009554     0.134185
# max_interactions_per_session                  0.124785     0.737453
# cart_pct_of_total_events                     -0.031631    -0.396659
# avg_purchases_per_session                    -0.027285    -0.304312
# purchase_events                               0.359093     0.227308
# sd_purchases_per_session                      1.000000     0.002269
# view_events                                   0.002269     1.000000
# sessions_with_purchase                        0.219623     0.235664
# sessions_with_view                            0.000465     0.755356
# pct_sessions_end_purchase                    -0.303561    -0.400806
# pct_sessions_end_cart                         0.202615     0.050192
# sd_session_length                            -0.013750     0.168932
# total_spend_log                               0.229082     0.030189
# total_events_log                              0.233302     0.637956
# purchase_events_log                           0.426708     0.222389
# total_sessions_log                            0.215818     0.617183
#
#                               sessions_with_purchase  sessions_with_view  \
# total_spend                                 0.488184            0.148906
# total_events                                0.387877            0.465337
# avg_session_length                          0.053639            0.156466
# max_interactions_per_session                0.140828            0.397881
# cart_pct_of_total_events                    0.072024           -0.342749
# avg_purchases_per_session                   0.112621           -0.386700
# purchase_events                             0.932698            0.339643
# sd_purchases_per_session                    0.219623            0.000465
# view_events                                 0.235664            0.755356
# sessions_with_purchase                      1.000000            0.384296
# sessions_with_view                          0.384296            1.000000
# pct_sessions_end_purchase                   0.078945           -0.490059
# pct_sessions_end_cart                       0.018408            0.077848
# sd_session_length                           0.070994            0.208555
# total_spend_log                             0.475812            0.114192
# total_events_log                            0.405391            0.635342
# purchase_events_log                         0.790096            0.319422
# total_sessions_log                          0.367441            0.791114
#
#                               pct_sessions_end_purchase  \
# total_spend                                    0.069628
# total_events                                  -0.171989
# avg_session_length                            -0.090676
# max_interactions_per_session                  -0.315549
# cart_pct_of_total_events                       0.541713
# avg_purchases_per_session                      0.829093
# purchase_events                                0.087018
# sd_purchases_per_session                      -0.303561
# view_events                                   -0.400806
# sessions_with_purchase                         0.078945
# sessions_with_view                            -0.490059
# pct_sessions_end_purchase                      1.000000
# pct_sessions_end_cart                         -0.301206
# sd_session_length                             -0.107775
# total_spend_log                                0.166302
# total_events_log                              -0.537190
# purchase_events_log                            0.098038
# total_sessions_log                            -0.794328
#
#                               pct_sessions_end_cart  sd_session_length  \
# total_spend                                0.009892           0.050417
# total_events                               0.048450           0.134815
# avg_session_length                         0.053622           0.948501
# max_interactions_per_session               0.055000           0.092205
# cart_pct_of_total_events                   0.211667          -0.037556
# avg_purchases_per_session                 -0.244417          -0.085614
# purchase_events                            0.013407           0.060594
# sd_purchases_per_session                   0.202615          -0.013750
# view_events                                0.050192           0.168932
# sessions_with_purchase                     0.018408           0.070994
# sessions_with_view                         0.077848           0.208555
# pct_sessions_end_purchase                 -0.301206          -0.107775
# pct_sessions_end_cart                      1.000000           0.056476
# sd_session_length                          0.056476           1.000000
# total_spend_log                            0.001625           0.031988
# total_events_log                           0.177961           0.152525
# purchase_events_log                        0.024858           0.063484
# total_sessions_log                         0.217211           0.179634
#
#                               total_spend_log  total_events_log  \
# total_spend                          0.536203          0.379234
# total_events                         0.350289          0.644777
# avg_session_length                   0.026239          0.136689
# max_interactions_per_session         0.007458          0.608817
# cart_pct_of_total_events             0.173938         -0.408516
# avg_purchases_per_session            0.242444         -0.351623
# purchase_events                      0.464972          0.381236
# sd_purchases_per_session             0.229082          0.233302
# view_events                          0.030189          0.637956
# sessions_with_purchase               0.475812          0.405391
# sessions_with_view                   0.114192          0.635342
# pct_sessions_end_purchase            0.166302         -0.537190
# pct_sessions_end_cart                0.001625          0.177961
# sd_session_length                    0.031988          0.152525
# total_spend_log                      1.000000          0.334137
# total_events_log                     0.334137          1.000000
# purchase_events_log                  0.599833          0.481189
# total_sessions_log                   0.134090          0.790438
#
#                               purchase_events_log  total_sessions_log
# total_spend                              0.441939            0.165674
# total_events                             0.361981            0.405858
# avg_session_length                       0.053213            0.146432
# max_interactions_per_session             0.201523            0.426848
# cart_pct_of_total_events                 0.102868           -0.463234
# avg_purchases_per_session                0.285990           -0.630276
# purchase_events                          0.793098            0.317658
# sd_purchases_per_session                 0.426708            0.215818
# view_events                              0.222389            0.617183
# sessions_with_purchase                   0.790096            0.367441
# sessions_with_view                       0.319422            0.791114
# pct_sessions_end_purchase                0.098038           -0.794328
# pct_sessions_end_cart                    0.024858            0.217211
# sd_session_length                        0.063484            0.179634
# total_spend_log                          0.599833            0.134090
# total_events_log                         0.481189            0.790438
# purchase_events_log                      1.000000            0.384584
# total_sessions_log                       0.384584            1.000000

# %% [markdown]
# ### Tested Models Adjusted R-Square Summary
#
# - All original inputs, original output: 0.61426 (21 variables)
# - Best original inputs, original output: 0.61334 (4 variables)
# - Original + Log-transformed inputs, normal output: 0.61582 (25 variables)
# - Smaller Original + Log-transformed inputs, normal output: 0.61617 (19 variables)

# %% [markdown]
# #### Our champion model has an adjusted R^2 of .61589, and uses 17 variables. However, it is possible to achieve an adjusted r^2 of .61334 using just 4 variables.
#
# Can we beat that by using a log-transformed output? (It's shown below, but the answer is no)

# %%
# Again, we iteratively tested features to find the best smaller set. Ultimately, we determined that the full set of variables gives the best performance. 
# The log-transformed response does not work nearly as well as the raw response. 

print("** All inputs, log-transformed output **")
inputCols = inputCols = ["total_spend", "total_sessions", "avg_session_length", "avg_interactions_per_session", "max_interactions_per_session",
             "purchase_pct_of_total_events", "view_pct_of_total_events", "cart_pct_of_total_events","avg_purchases_per_session", "cart_events", "purchase_events",
              "sessions_with_purchase","sessions_with_view", "pct_sessions_end_purchase", "pct_sessions_end_cart", 'sd_session_length', 
             'sd_interactions_per_session', 'sd_purchases_per_session', "total_spend_log", "total_events_log", "purchase_events_log", "total_sessions_log"]
outputCol = "T_total_spend_log"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** All inputs, log-transformed output **
# Model coefficients
#                      Column name  Coefficient       pValues
# 0                      intercept    10.837386  0.000000e+00
# 1                    total_spend    -0.000126  0.000000e+00
# 2                 total_sessions     0.414863  4.051154e-05
# 3             avg_session_length    -0.000021  0.000000e+00
# 4   avg_interactions_per_session    -0.326426  0.000000e+00
# 5   max_interactions_per_session    -0.026669  9.999937e-01
# 6   purchase_pct_of_total_events     0.319616  9.993103e-01
# 7       view_pct_of_total_events   -30.691944  9.994139e-01
# 8       cart_pct_of_total_events   -26.082067  0.000000e+00
# 9      avg_purchases_per_session    -2.249517  0.000000e+00
# 10                   cart_events    -0.085133  7.152812e-05
# 11               purchase_events    -0.049146  0.000000e+00
# 12        sessions_with_purchase     0.338287  0.000000e+00
# 13            sessions_with_view    -0.418970  0.000000e+00
# 14     pct_sessions_end_purchase    -4.693333  0.000000e+00
# 15         pct_sessions_end_cart    -1.745909  7.478047e-10
# 16             sd_session_length     0.000008  0.000000e+00
# 17   sd_interactions_per_session    -0.184599  2.030464e-06
# 18      sd_purchases_per_session     0.258645  0.000000e+00
# 19               total_spend_log     0.449583  0.000000e+00
# 20              total_events_log     8.078556  0.000000e+00
# 21           purchase_events_log    -0.777515  0.000000e+00
# 22            total_sessions_log    -6.507399  9.997564e-01
# +------------------+-------------------+
# | T_total_spend_log|         prediction|
# +------------------+-------------------+
# |-6.907755278982137|-3.4442585387153315|
# |-6.907755278982137|-1.9925963107002733|
# |-6.907755278982137|-3.2220887343479276|
# |-6.907755278982137| -8.685465282846351|
# |-6.907755278982137|-5.1038014601924395|
# |-6.907755278982137| -9.021414100190764|
# |-6.907755278982137|-4.6279968736932435|
# |-6.907755278982137| -2.955697767695609|
# |11.278695703691795| 14.984702673105623|
# |6.4970781070591626|-1.2423502112905886|
# +------------------+-------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 5.0
# R^2 is 0.50137
# Adjusted R^2 is 0.50121

# %% [markdown]
# ### Test out different combinations of hyperparameters
#
# Here we test out 25 combinations of hyperparameters on our best linear regression model under cross validation.
#
# - Regularization parameters: [0, 0.01, 0.2, 1, 10]
# - Amount of LASSO-ness: [0, 0.25, 0.5, 0.75, 1]

# %%
# Change evaluation metrics so they work for CV
# def getEvaluationMetricsCV(cvModel,outputCol,testDF,inputCols):
#     predDF = cvModel.transform(testDF).
#     predDF.select(outputCol, "prediction").show(10)
    
#     print(predDF)
    
#     regressionEvaluator = RegressionEvaluator(
#     predictionCol="prediction",
#     labelCol=outputCol,
#     metricName="rmse")
#     rmse = regressionEvaluator.evaluate(predDF)

#     regressionEvaluator = RegressionEvaluator(
#     predictionCol="prediction",
#     labelCol=outputCol,
#     metricName="r2")
#     r2 = regressionEvaluator.evaluate(predDF)
      
#     # Manually calculate Adjusted r2
#     adjusted_r2 = adj_r2(r2, inputCols, testDF)
    
#     return rmse, r2, adjusted_r2

# %%
# pvalues breaks when used with this so taking that out
def modelInfo2(inputCols, pipelineModel):
    # Create a zipped list containing the coefficients and the data
    modelCols = copy.deepcopy(inputCols)
    modelCoeffs = list(pipelineModel.stages[-1].coefficients)
    modelCoeffs.insert(0,pipelineModel.stages[-1].intercept)
    modelCols.insert(0,"intercept")
    modelZippedList = list(map(list, zip(modelCols, modelCoeffs)))
        
    # Create the pandas DataFrame
    modelDF = pd.DataFrame(modelZippedList, columns = ['Column name', 'Coefficient'])
    
    return modelDF

# %%
# %%time
print("** Champion adj-r-square **")
inputCols = ["total_spend", "total_events","avg_session_length", "avg_interactions_per_session", "view_events",
             'sd_interactions_per_session', 'sd_purchases_per_session', "total_spend_log", "total_events_log", "purchase_events",  "purchase_events_log", "total_sessions_log",
             "max_interactions_per_session",  "total_sessions", "view_pct_of_total_events", "sd_session_length", "pct_sessions_end_purchase"]
outputCol = "T_total_spend"
# Below creation of pipeline is necessary for crossval to run. I wonder if there's a way to get it to run on the generate pipeline fn? 
vecAssembler = VectorAssembler(inputCols=inputCols, outputCol="features")

# Select output column for linear regression
lr = LinearRegression(featuresCol="features", labelCol="T_total_spend")

pipeline = Pipeline(stages=[vecAssembler, lr])
    
paramGrid = ParamGridBuilder() \
    .addGrid(lr.regParam, [0, 0.01, 0.2, 1, 10]) \
    .addGrid(lr.elasticNetParam, [0, 0.25, 0.5, 0.75, 1]) \
    .build()

crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=RegressionEvaluator().setLabelCol("T_total_spend"),
                          numFolds=4)

# Run cross-validation, and choose the best set of parameters.
cvModel = crossval.fit(trainDF)
# Out:
# ** Champion adj-r-square **
# CPU times: user 4.44 s, sys: 1.34 s, total: 5.78 s
# Wall time: 1min 28s

# %%
# print(cvModel.getEstimatorParamMaps()[np.argmax(cvModel.avgMetrics)])

# %%
print("Best model coefficients")
print(modelInfo2(inputCols, cvModel.bestModel))

#evaluationMetrics = getEvaluationMetricsCV(cvModel.bestModel,"T_total_spend",testDF,inputCols)
evaluationMetrics = getEvaluationMetrics(cvModel.bestModel,"T_total_spend",testDF,inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")

print()
print(cvModel.getEstimatorParamMaps()[np.argmax(cvModel.avgMetrics)])
# Out:
# Best model coefficients
#                      Column name   Coefficient
# 0                      intercept   3339.589946
# 1                    total_spend      3.949472
# 2                   total_events    221.689208
# 3             avg_session_length     -0.147394
# 4   avg_interactions_per_session   -270.164405
# 5                    view_events   -198.215613
# 6    sd_interactions_per_session    -89.245144
# 7       sd_purchases_per_session  -5429.616294
# 8                total_spend_log   1469.072840
# 9               total_events_log   1302.806603
# 10               purchase_events  -2801.345903
# 11           purchase_events_log   5849.824343
# 12            total_sessions_log  -8681.086075
# 13  max_interactions_per_session    100.144892
# 14                total_sessions    353.863859
# 15      view_pct_of_total_events   8164.812837
# 16             sd_session_length      0.077834
# 17     pct_sessions_end_purchase -17286.792616
# +-----------------+-------------------+
# |    T_total_spend|         prediction|
# +-----------------+-------------------+
# |              0.0|  6733.428282916042|
# |              0.0| 4672.8664087069865|
# |              0.0|  3927.281379368127|
# |              0.0|-1938.4731093562282|
# |              0.0| -602.2080729864838|
# |              0.0| -2639.196513733323|
# |              0.0|  2209.996663591703|
# |              0.0|   8507.85001621393|
# |79118.00024795532| 145841.65169158066|
# |663.1999969482422|   7638.20115084526|
# +-----------------+-------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 43387.8
# R^2 is 0.61598
# Adjusted R^2 is 0.61589
#
# {Param(parent='LinearRegression_3e13d8ea513b', name='regParam', doc='regularization parameter (>= 0).'): 1.0, Param(parent='LinearRegression_3e13d8ea513b', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 0.25}

# %% [markdown]
# ## Double-checking if the values truly come out the same with those selected parameters.

# %%
# %%time
# This pipeline model contains the optimized parameters chosen by our model
def generateOptimizedPipeline(inputCols, outputCol):
    # Select input columns for linear regression
    vecAssembler = VectorAssembler(inputCols=inputCols, outputCol="features")

    # Select output column for linear regression
    lr = LinearRegression(featuresCol="features", labelCol=outputCol, regParam = 1.0, elasticNetParam = .25)

    # The following lines (pipeline creation and fitting) replace these two commented-out lines.
    # vecTrainDF = vecAssembler.transform(trainDF)
 
    pipeline = Pipeline(stages=[vecAssembler, lr])
    return pipeline
    
pipeline = generatePipeline(inputCols, "T_total_spend")
pipelineModel = pipeline.fit(trainDF)
# Out:
# CPU times: user 17.1 ms, sys: 6.41 ms, total: 23.5 ms
# Wall time: 697 ms

# %%
print("** All original inputs, original output **")
inputCols = ["total_spend", "total_events","avg_session_length", "avg_interactions_per_session", "view_events",
             'sd_interactions_per_session', 'sd_purchases_per_session', "total_spend_log", "total_events_log", "purchase_events",  "purchase_events_log", "total_sessions_log",
             "max_interactions_per_session",  "total_sessions", "view_pct_of_total_events", "sd_session_length", "pct_sessions_end_purchase"]

outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** All original inputs, original output **
# Model coefficients
#                      Column name   Coefficient       pValues
# 0                      intercept   3687.902619  0.000000e+00
# 1                    total_spend      3.947723  0.000000e+00
# 2                   total_events    221.630879  6.005486e-04
# 3             avg_session_length     -0.150080  0.000000e+00
# 4   avg_interactions_per_session   -276.349453  0.000000e+00
# 5                    view_events   -198.527398  4.753246e-02
# 6    sd_interactions_per_session    -82.836690  0.000000e+00
# 7       sd_purchases_per_session  -5558.501378  0.000000e+00
# 8                total_spend_log   1462.262768  5.295764e-13
# 9               total_events_log   1355.420234  0.000000e+00
# 10               purchase_events  -2800.436050  0.000000e+00
# 11           purchase_events_log   5966.777828  0.000000e+00
# 12            total_sessions_log  -8878.314122  7.793396e-08
# 13  max_interactions_per_session     99.208006  0.000000e+00
# 14                total_sessions    360.033292  0.000000e+00
# 15      view_pct_of_total_events   8119.329512  5.499601e-12
# 16             sd_session_length      0.078555  0.000000e+00
# 17     pct_sessions_end_purchase -17634.947714  3.490233e-03
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +-----------------+-------------------+
# |    T_total_spend|         prediction|
# +-----------------+-------------------+
# |              0.0|  6778.458976215637|
# |              0.0|  4682.719480841732|
# |              0.0|  3958.719200093649|
# |              0.0|-1974.8521856186758|
# |              0.0|  -603.022182237632|
# |              0.0|-2667.5343679325592|
# |              0.0|  2235.043912387607|
# |              0.0|  8496.518740025671|
# |79118.00024795532| 145889.89692787064|
# |663.1999969482422|  7637.688860541013|
# +-----------------+-------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 43387.5
# R^2 is 0.61599
# Adjusted R^2 is 0.61589

# %% [markdown]
# #### It appears that in this case, selection of regularization parameters is inconsequential. The model performed essentially the same using the default parameters as it did using the parameters selected as the best by the crossvalidator, indicating that the differences are minute. It's not that the crossvalidator selected all the same parameters - it selected a regParam of 1 and elasticNetParam of .25.

# %% [markdown]
# ### Save pipeline model and get model size
# ##### CHECK NEW SIZE
# The model size is ____ kB, according to the file explorer in Linux.

# %%
pipelinePath = "models/lr-pipeline-model_NewData"
cvModel.bestModel.write().overwrite().save(pipelinePath)

# %% [markdown]
# #### Our data is extremely zero-inflated. If we downsample the data so our response variable =0 only about half the time, can we beat the model performance above? The number to beat is an adjusted r-square of .61589

# %%
# %%time
trainDF_ds = spark.read.parquet("./processed_data/ds_train.parquet")
testDF_ds = spark.read.parquet("./processed_data/ds_test.parquet")
# Out:
# CPU times: user 3.33 ms, sys: 535 µs, total: 3.86 ms
# Wall time: 191 ms

# %%
trainDF_ds = trainDF_ds \
          .withColumn("total_spend_log", log(col("total_spend")+0.001)) \
          .withColumn("total_events_log", log(col("total_events")+0.001)) \
          .withColumn("purchase_events_log", log(col("purchase_events")+0.001)) \
          .withColumn("total_sessions_log", log(col("total_sessions")+0.001)) \
          .withColumn("T_total_spend_log", log(col("T_total_spend")+0.001))

testDF_ds = testDF_ds \
          .withColumn("total_spend_log", log(col("total_spend")+0.001)) \
          .withColumn("total_events_log", log(col("total_events")+0.001)) \
          .withColumn("purchase_events_log", log(col("purchase_events")+0.001)) \
          .withColumn("total_sessions_log", log(col("total_sessions")+0.001)) \
          .withColumn("T_total_spend_log", log(col("T_total_spend")+0.001))

# %%
#"cart_pct_of_total_events" oddly this one breaks it? Not important, it's not a good predictor anyway

print("** Original + Log-transformed inputs, normal output **")
inputCols = ["total_spend","total_events","purchase_events", "total_sessions", "avg_session_length", "avg_interactions_per_session", "max_interactions_per_session",
             "purchase_pct_of_total_events", "view_pct_of_total_events","avg_purchases_per_session", "cart_events", "view_events", 
             "sessions_with_purchase", "sessions_with_cart","sessions_with_view", "pct_sessions_end_purchase", "pct_sessions_end_cart", 'sd_session_length', 
             'sd_interactions_per_session', 'sd_purchases_per_session']
outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF_ds)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF_ds, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** Original + Log-transformed inputs, normal output **
# Model coefficients
#                      Column name   Coefficient       pValues
# 0                      intercept  -8061.148243  0.000000e+00
# 1                    total_spend      4.360910  0.000000e+00
# 2                   total_events    215.828050  0.000000e+00
# 3                purchase_events  -3723.415567  5.391370e-05
# 4                 total_sessions   1070.623981  2.627864e-01
# 5             avg_session_length     -0.091686  1.613769e-05
# 6   avg_interactions_per_session   -300.344446  3.289889e-08
# 7   max_interactions_per_session    200.190515  7.547815e-03
# 8   purchase_pct_of_total_events -14144.069142  1.023383e-07
# 9       view_pct_of_total_events  13252.029420  6.534423e-01
# 10     avg_purchases_per_session   -394.147528  1.805919e-02
# 11                   cart_events    137.187457  0.000000e+00
# 12                   view_events   -175.830322  2.449210e-03
# 13        sessions_with_purchase  -1006.174796  6.189360e-10
# 14            sessions_with_cart   1339.434342  1.356691e-03
# 15            sessions_with_view   -838.449566  1.075552e-03
# 16     pct_sessions_end_purchase   5049.589736  6.154401e-03
# 17         pct_sessions_end_cart  -4789.340678  3.068501e-03
# 18             sd_session_length      0.062538  2.589490e-02
# 19   sd_interactions_per_session   -193.111201  4.139066e-03
# 20      sd_purchases_per_session   2081.593129  1.113473e-03
# +-----------------+------------------+
# |    T_total_spend|        prediction|
# +-----------------+------------------+
# |              0.0| 8935.797728219562|
# |              0.0|7471.7443504451185|
# |              0.0| 9457.458266151663|
# |              0.0| 5295.314231855935|
# |              0.0| 7723.734426878318|
# |              0.0|3760.4944101680358|
# |              0.0|4056.8489021594705|
# |              0.0|11799.475086855184|
# |79118.00024795532|143730.73386088328|
# |663.1999969482422|10652.924910567863|
# +-----------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, T_total_spend: double, total_spend: double, total_events: bigint, total_sessions: bigint, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 43786.9
# R^2 is 0.60888
# Adjusted R^2 is 0.60877

# %% [markdown]
# #### Interestingly, downsampling the inflated 0s doesn't seem to help at all on the test set!
