# %% [markdown]
# ## File 05 - Linear Regression
# ##### Group 12:
#
# ##### Hannah Schmuckler, mmc4cv
#
# ##### Rob Schwartz, res7cd
# In this file, we create a small ML pipeline based on the output from File 02 (Feature creation).
#
# We create a linear regression model, tune it, then compare it to a linear regression model created with downsampled data to see how performance compares.

# %% [markdown]
# ### Set up Spark session
#
# We can specify more options in the SparkSession creator, but currently the options are at the default settings.

# %%
# %%time
from pyspark.sql import SparkSession
from pyspark.sql import types as T
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.regression import LinearRegression, LinearRegressionModel, LinearRegressionSummary
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.sql.functions import col
from pyspark.sql.functions import log
from pyspark.ml.stat import Correlation

import pandas as pd
import numpy as np
import copy

spark = SparkSession.builder \
        .appName("project") \
        .getOrCreate()

sc = spark.sparkContext
# Out:
# CPU times: user 394 ms, sys: 327 ms, total: 722 ms
# Wall time: 4.49 s

# %% [markdown]
# ### Read in dataframes for train and test sets
#
# This data should have been previously generated: we can find it in the `processed_data` folder.

# %%
# %%time
trainDF = spark.read.parquet("./processed_data/train.parquet")
testDF = spark.read.parquet("./processed_data/test.parquet")
# trainDF.show(5)
# Out:
# CPU times: user 2.6 ms, sys: 0 ns, total: 2.6 ms
# Wall time: 2.3 s

# %%
trainDF.printSchema()
# Out:
# root
#  |-- user_id: integer (nullable = true)
#  |-- total_spend: double (nullable = true)
#  |-- total_events: long (nullable = true)
#  |-- total_sessions: long (nullable = true)
#  |-- T_total_spend: double (nullable = true)
#  |-- avg_session_length: double (nullable = true)
#  |-- sd_session_length: double (nullable = true)
#  |-- avg_interactions_per_session: double (nullable = true)
#  |-- sd_interactions_per_session: double (nullable = true)
#  |-- max_interactions_per_session: long (nullable = true)
#  |-- purchase_pct_of_total_events: double (nullable = true)
#  |-- view_pct_of_total_events: double (nullable = true)
#  |-- cart_pct_of_total_events: double (nullable = true)
#  |-- avg_purchases_per_session: double (nullable = true)
#  |-- sd_purchases_per_session: double (nullable = true)
#  |-- cart_events: long (nullable = true)
#  |-- purchase_events: long (nullable = true)
#  |-- view_events: long (nullable = true)
#  |-- sessions_with_purchase: long (nullable = true)
#  |-- sessions_with_cart: long (nullable = true)
#  |-- sessions_with_view: long (nullable = true)
#  |-- pct_sessions_end_purchase: double (nullable = true)
#  |-- pct_sessions_end_cart: double (nullable = true)
#  |-- total_spend_log: double (nullable = true)
#  |-- total_events_log: double (nullable = true)
#  |-- purchase_events_log: double (nullable = true)
#  |-- total_sessions_log: double (nullable = true)
#  |-- avg_session_length_log: double (nullable = true)
#  |-- T_total_spend_log: double (nullable = true)
#  |-- pca_purchases10: vector (nullable = true)
#  |-- pca_purchases20: vector (nullable = true)
#  |-- pca_purchases50: vector (nullable = true)
#  |-- pca_purchases100: vector (nullable = true)

# %% [markdown]
# ### Set up Spark ML pipeline training for linear regression
#
# Here we decide which input columns should be used in order to create our training pipeline. To implement this step, we create the function `generatePipeline(inputCols, outputCol)`. Then, we train the pipeline using this function.

# %%
# %%time

def generatePipeline(inputCols, outputCol):
    # Select input columns for linear regression
    vecAssembler = VectorAssembler(inputCols=inputCols, outputCol="unscaled_features")
    # Scale features
    ss = StandardScaler(inputCol = "unscaled_features", outputCol = "features", withMean = True, withStd = True)
    # Select output column for linear regression
    lr = LinearRegression(featuresCol="features", labelCol=outputCol)

 
    pipeline = Pipeline(stages=[vecAssembler, ss, lr])
    return pipeline
# Out:
# CPU times: user 0 ns, sys: 2 µs, total: 2 µs
# Wall time: 4.77 µs

# %% [markdown]
# ### View the model information
#
# Print out the model coefficients and view the pValues, RMSE and R^2. We define the functions `modelInfo(inputCols, pipelineModel)` and `getEvaluationMetrics(pipelineModel,outputCol,testDF)` to report this information.

# %%
def modelInfo(inputCols, pipelineModel):
    # Create a zipped list containing the coefficients and the data
    modelCols = copy.deepcopy(inputCols)
    modelCoeffs = list(pipelineModel.stages[-1].coefficients)
    modelCoeffs.insert(0,pipelineModel.stages[-1].intercept)
    modelCols.insert(0,"intercept")
    modelZippedList = list(map(list, zip(modelCols, modelCoeffs)))
    
    # Add in the p-values
    pvals = pipelineModel.stages[-1].summary.pValues
    
    # Create the pandas DataFrame
    modelDF = pd.DataFrame(modelZippedList, columns = ['Column name', 'Coefficient'])
    modelDF['pValues'] = pvals
    return modelDF

# %%
# Calculate adjusted r2 (https://towardsdatascience.com/machine-learning-linear-regression-using-pyspark-9d5d5c772b42)
# This function will allow us to calculate the adjusted r-square value when we do PCA later. The default r-square function does not take into account k. 
def adj_r2(r2, inputCols, testDF, k = 0):
    n = testDF.count()
    if k == 0:
        p = len(inputCols)
    else: 
        p = len(inputCols) + k - 1
    
    adjusted_r2 = 1-(((1-r2)*(n-1))/(n-p-1))
    return adjusted_r2

# %%
def getEvaluationMetrics(pipelineModel,outputCol,testDF,inputCols):
    predDF = pipelineModel.transform(testDF)
    print()
    print('type preddf' + str(type(predDF)))
    print()
    predDF.select(outputCol, "prediction").show(10)
    
    print(predDF)
    
    regressionEvaluator = RegressionEvaluator(
    predictionCol="prediction",
    labelCol=outputCol,
    metricName="rmse")
    rmse = regressionEvaluator.evaluate(predDF)

    regressionEvaluator = RegressionEvaluator(
    predictionCol="prediction",
    labelCol=outputCol,
    metricName="r2")
    r2 = regressionEvaluator.evaluate(predDF)
      
    # Manually calculate Adjusted r2
    adjusted_r2 = adj_r2(r2, inputCols, testDF)
    
    return rmse, r2, adjusted_r2

# %%
# Comprehensive
inputCols = ["total_spend", "total_events", "total_sessions", "avg_session_length", "sd_session_length", "avg_interactions_per_session", 
             "sd_interactions_per_session", "max_interactions_per_session", "purchase_pct_of_total_events", "view_pct_of_total_events",
             "cart_pct_of_total_events", "avg_purchases_per_session", "sd_purchases_per_session", "cart_events", "purchase_events", 
             "sessions_with_purchase", "sessions_with_cart", "sessions_with_view", "pct_sessions_end_purchase", 
             "pct_sessions_end_cart", "total_spend_log", "total_events_log", "purchase_events_log", "total_sessions_log",
             "avg_session_length_log"]

# %% [markdown]
# ### There's likely collinearity between some of these features. Let's take a look at a correlation matrix:

# %%
#Create function to view correlation matrices
# https://stackoverflow.com/questions/52214404/how-to-get-the-correlation-matrix-of-a-pyspark-data-frame
def generateCorrMatrix(inputCols, dataframe):
    # Select input columns for Correlation Matrix & transform
    vector_col = 'corr_features'
    corrAssembler = VectorAssembler(inputCols=inputCols, outputCol=vector_col)
    df_vector = corrAssembler.transform(dataframe).select(vector_col)
    
    #get correlation matrix
    matrix = Correlation.corr(df_vector, vector_col)
    result = matrix.collect()[0]["pearson({})".format(vector_col)].values
    readable = pd.DataFrame(result.reshape(-1, len(inputCols)), columns=inputCols, index=inputCols)
    
    return readable

# %%
generateCorrMatrix(inputCols, trainDF)
# Out:
#                               total_spend  total_events  total_sessions  \
# total_spend                      1.000000      0.267576        0.297334
# total_events                     0.267576      1.000000        0.789305
# total_sessions                   0.297334      0.789305        1.000000
# avg_session_length               0.074837      0.054993        0.082139
# sd_session_length                0.099307      0.111465        0.164686
# avg_interactions_per_session     0.009718      0.291275       -0.033912
# sd_interactions_per_session      0.038839      0.526505        0.237057
# max_interactions_per_session     0.092811      0.722697        0.397175
# purchase_pct_of_total_events     0.107863     -0.369753       -0.369811
# view_pct_of_total_events        -0.117347      0.380738        0.365643
# cart_pct_of_total_events         0.100036     -0.310455       -0.287647
# avg_purchases_per_session        0.171878     -0.237634       -0.346058
# sd_purchases_per_session         0.244761      0.074975        0.023334
# cart_events                      0.617555      0.515323        0.530208
# purchase_events                  0.765931      0.423932        0.431841
# sessions_with_purchase           0.709111      0.422810        0.482276
# sessions_with_cart               0.626564      0.533934        0.638601
# sessions_with_view               0.285545      0.793259        0.993768
# pct_sessions_end_purchase        0.088643     -0.348755       -0.448364
# pct_sessions_end_cart            0.016506      0.077966        0.101794
# total_spend_log                  0.487793      0.115701        0.146120
# total_events_log                 0.201547      0.736466        0.694987
# purchase_events_log              0.514174      0.368157        0.386997
# total_sessions_log               0.204204      0.635699        0.782182
# avg_session_length_log           0.077570      0.255801        0.181336
#
#                               avg_session_length  sd_session_length  \
# total_spend                             0.074837           0.099307
# total_events                            0.054993           0.111465
# total_sessions                          0.082139           0.164686
# avg_session_length                      1.000000           0.834726
# sd_session_length                       0.834726           1.000000
# avg_interactions_per_session           -0.008058          -0.029591
# sd_interactions_per_session             0.018618           0.034662
# max_interactions_per_session            0.028854           0.054289
# purchase_pct_of_total_events           -0.037597          -0.072183
# view_pct_of_total_events               -0.026544           0.001362
# cart_pct_of_total_events                0.066853           0.049438
# avg_purchases_per_session              -0.029498          -0.073418
# sd_purchases_per_session                0.024039           0.024866
# cart_events                             0.139563           0.196900
# purchase_events                         0.068806           0.097417
# sessions_with_purchase                  0.075846           0.111145
# sessions_with_cart                      0.127129           0.199970
# sessions_with_view                      0.065021           0.137877
# pct_sessions_end_purchase              -0.045000          -0.096415
# pct_sessions_end_cart                   0.082164           0.113910
# total_spend_log                         0.044350           0.055072
# total_events_log                        0.073224           0.132356
# purchase_events_log                     0.071939           0.103713
# total_sessions_log                      0.085964           0.163273
# avg_session_length_log                  0.570257           0.685703
#
#                               avg_interactions_per_session  \
# total_spend                                       0.009718
# total_events                                      0.291275
# total_sessions                                   -0.033912
# avg_session_length                               -0.008058
# sd_session_length                                -0.029591
# avg_interactions_per_session                      1.000000
# sd_interactions_per_session                       0.555439
# max_interactions_per_session                      0.629323
# purchase_pct_of_total_events                     -0.274950
# view_pct_of_total_events                          0.229046
# cart_pct_of_total_events                         -0.149305
# avg_purchases_per_session                         0.250593
# sd_purchases_per_session                          0.050988
# cart_events                                       0.116446
# purchase_events                                   0.051433
# sessions_with_purchase                            0.003659
# sessions_with_cart                               -0.008019
# sessions_with_view                               -0.028986
# pct_sessions_end_purchase                         0.122442
# pct_sessions_end_cart                            -0.019660
# total_spend_log                                  -0.013982
# total_events_log                                  0.351459
# purchase_events_log                               0.083284
# total_sessions_log                               -0.087016
# avg_session_length_log                            0.320714
#
#                               sd_interactions_per_session  \
# total_spend                                      0.038839
# total_events                                     0.526505
# total_sessions                                   0.237057
# avg_session_length                               0.018618
# sd_session_length                                0.034662
# avg_interactions_per_session                     0.555439
# sd_interactions_per_session                      1.000000
# max_interactions_per_session                     0.873582
# purchase_pct_of_total_events                    -0.474157
# view_pct_of_total_events                         0.454473
# cart_pct_of_total_events                        -0.347183
# avg_purchases_per_session                       -0.247400
# sd_purchases_per_session                         0.322893
# cart_events                                      0.211455
# purchase_events                                  0.108130
# sessions_with_purchase                           0.075191
# sessions_with_cart                               0.117955
# sessions_with_view                               0.242911
# pct_sessions_end_purchase                       -0.388312
# pct_sessions_end_cart                            0.082515
# total_spend_log                                 -0.017801
# total_events_log                                 0.628156
# purchase_events_log                              0.159523
# total_sessions_log                               0.383093
# avg_session_length_log                           0.268427
#
#                               max_interactions_per_session  \
# total_spend                                       0.092811
# total_events                                      0.722697
# total_sessions                                    0.397175
# avg_session_length                                0.028854
# sd_session_length                                 0.054289
# avg_interactions_per_session                      0.629323
# sd_interactions_per_session                       0.873582
# max_interactions_per_session                      1.000000
# purchase_pct_of_total_events                     -0.451875
# view_pct_of_total_events                          0.442540
# cart_pct_of_total_events                         -0.345082
# avg_purchases_per_session                        -0.164080
# sd_purchases_per_session                          0.148493
# cart_events                                       0.302561
# purchase_events                                   0.190243
# sessions_with_purchase                            0.155269
# sessions_with_cart                                0.220849
# sessions_with_view                                0.403390
# pct_sessions_end_purchase                        -0.306974
# pct_sessions_end_cart                             0.054627
# total_spend_log                                   0.017614
# total_events_log                                  0.695921
# purchase_events_log                               0.223670
# total_sessions_log                                0.430422
# avg_session_length_log                            0.311904
#
#                               purchase_pct_of_total_events  \
# total_spend                                       0.107863
# total_events                                     -0.369753
# total_sessions                                   -0.369811
# avg_session_length                               -0.037597
# sd_session_length                                -0.072183
# avg_interactions_per_session                     -0.274950
# sd_interactions_per_session                      -0.474157
# max_interactions_per_session                     -0.451875
# purchase_pct_of_total_events                      1.000000
# view_pct_of_total_events                         -0.828854
# cart_pct_of_total_events                          0.536704
# avg_purchases_per_session                         0.666720
# sd_purchases_per_session                         -0.113817
# cart_events                                      -0.094889
# purchase_events                                   0.092291
# sessions_with_purchase                            0.078746
# sessions_with_cart                               -0.071200
# sessions_with_view                               -0.374835
# pct_sessions_end_purchase                         0.769086
# pct_sessions_end_cart                            -0.252300
# total_spend_log                                   0.209643
# total_events_log                                 -0.720444
# purchase_events_log                               0.115240
# total_sessions_log                               -0.613472
# avg_session_length_log                           -0.296796
#
#                               view_pct_of_total_events  ...  \
# total_spend                                  -0.117347  ...
# total_events                                  0.380738  ...
# total_sessions                                0.365643  ...
# avg_session_length                           -0.026544  ...
# sd_session_length                             0.001362  ...
# avg_interactions_per_session                  0.229046  ...
# sd_interactions_per_session                   0.454473  ...
# max_interactions_per_session                  0.442540  ...
# purchase_pct_of_total_events                 -0.828854  ...
# view_pct_of_total_events                      1.000000  ...
# cart_pct_of_total_events                     -0.916909  ...
# avg_purchases_per_session                    -0.619381  ...
# sd_purchases_per_session                      0.066447  ...
# cart_events                                  -0.094562  ...
# purchase_events                              -0.099311  ...
# sessions_with_purchase                       -0.090975  ...
# sessions_with_cart                           -0.021904  ...
# sessions_with_view                            0.380505  ...
# pct_sessions_end_purchase                    -0.716757  ...
# pct_sessions_end_cart                        -0.030546  ...
# total_spend_log                              -0.230949  ...
# total_events_log                              0.652967  ...
# purchase_events_log                          -0.130654  ...
# total_sessions_log                            0.578633  ...
# avg_session_length_log                        0.206277  ...
#
#                               sessions_with_purchase  sessions_with_cart  \
# total_spend                                 0.709111            0.626564
# total_events                                0.422810            0.533934
# total_sessions                              0.482276            0.638601
# avg_session_length                          0.075846            0.127129
# sd_session_length                           0.111145            0.199970
# avg_interactions_per_session                0.003659           -0.008019
# sd_interactions_per_session                 0.075191            0.117955
# max_interactions_per_session                0.155269            0.220849
# purchase_pct_of_total_events                0.078746           -0.071200
# view_pct_of_total_events                   -0.090975           -0.021904
# cart_pct_of_total_events                    0.081032            0.083825
# avg_purchases_per_session                   0.120180           -0.030464
# sd_purchases_per_session                    0.218349            0.180532
# cart_events                                 0.772708            0.863915
# purchase_events                             0.931722            0.817842
# sessions_with_purchase                      1.000000            0.884357
# sessions_with_cart                          0.884357            1.000000
# sessions_with_view                          0.474429            0.602891
# pct_sessions_end_purchase                   0.079073           -0.093665
# pct_sessions_end_cart                       0.027172            0.287873
# total_spend_log                             0.440114            0.372850
# total_events_log                            0.355360            0.473317
# purchase_events_log                         0.740647            0.663047
# total_sessions_log                          0.367864            0.506261
# avg_session_length_log                      0.090265            0.175449
#
#                               sessions_with_view  pct_sessions_end_purchase  \
# total_spend                             0.285545                   0.088643
# total_events                            0.793259                  -0.348755
# total_sessions                          0.993768                  -0.448364
# avg_session_length                      0.065021                  -0.045000
# sd_session_length                       0.137877                  -0.096415
# avg_interactions_per_session           -0.028986                   0.122442
# sd_interactions_per_session             0.242911                  -0.388312
# max_interactions_per_session            0.403390                  -0.306974
# purchase_pct_of_total_events           -0.374835                   0.769086
# view_pct_of_total_events                0.380505                  -0.716757
# cart_pct_of_total_events               -0.306478                   0.532365
# avg_purchases_per_session              -0.347935                   0.830946
# sd_purchases_per_session                0.023664                  -0.282554
# cart_events                             0.500167                  -0.070775
# purchase_events                         0.424584                   0.081996
# sessions_with_purchase                  0.474429                   0.079073
# sessions_with_cart                      0.602891                  -0.093665
# sessions_with_view                      1.000000                  -0.450907
# pct_sessions_end_purchase              -0.450907                   1.000000
# pct_sessions_end_cart                   0.082713                  -0.303628
# total_spend_log                         0.142192                   0.189014
# total_events_log                        0.699922                  -0.624865
# purchase_events_log                     0.384030                   0.101585
# total_sessions_log                      0.783236                  -0.774152
# avg_session_length_log                  0.162298                  -0.083607
#
#                               pct_sessions_end_cart  total_spend_log  \
# total_spend                                0.016506         0.487793
# total_events                               0.077966         0.115701
# total_sessions                             0.101794         0.146120
# avg_session_length                         0.082164         0.044350
# sd_session_length                          0.113910         0.055072
# avg_interactions_per_session              -0.019660        -0.013982
# sd_interactions_per_session                0.082515        -0.017801
# max_interactions_per_session               0.054627         0.017614
# purchase_pct_of_total_events              -0.252300         0.209643
# view_pct_of_total_events                  -0.030546        -0.230949
# cart_pct_of_total_events                   0.226048         0.198761
# avg_purchases_per_session                 -0.245602         0.271909
# sd_purchases_per_session                   0.194940         0.242639
# cart_events                                0.242814         0.343615
# purchase_events                            0.021150         0.421490
# sessions_with_purchase                     0.027172         0.440114
# sessions_with_cart                         0.287873         0.372850
# sessions_with_view                         0.082713         0.142192
# pct_sessions_end_purchase                 -0.303628         0.189014
# pct_sessions_end_cart                      1.000000         0.001163
# total_spend_log                            0.001163         1.000000
# total_events_log                           0.202753         0.130275
# purchase_events_log                        0.036549         0.602141
# total_sessions_log                         0.225033         0.133369
# avg_session_length_log                     0.079523         0.026784
#
#                               total_events_log  purchase_events_log  \
# total_spend                           0.201547             0.514174
# total_events                          0.736466             0.368157
# total_sessions                        0.694987             0.386997
# avg_session_length                    0.073224             0.071939
# sd_session_length                     0.132356             0.103713
# avg_interactions_per_session          0.351459             0.083284
# sd_interactions_per_session           0.628156             0.159523
# max_interactions_per_session          0.695921             0.223670
# purchase_pct_of_total_events         -0.720444             0.115240
# view_pct_of_total_events              0.652967            -0.130654
# cart_pct_of_total_events             -0.470857             0.114843
# avg_purchases_per_session            -0.415153             0.287199
# sd_purchases_per_session              0.233399             0.434930
# cart_events                           0.456628             0.609898
# purchase_events                       0.332017             0.713975
# sessions_with_purchase                0.355360             0.740647
# sessions_with_cart                    0.473317             0.663047
# sessions_with_view                    0.699922             0.384030
# pct_sessions_end_purchase            -0.624865             0.101585
# pct_sessions_end_cart                 0.202753             0.036549
# total_spend_log                       0.130275             0.602141
# total_events_log                      1.000000             0.455346
# purchase_events_log                   0.455346             1.000000
# total_sessions_log                    0.868504             0.419871
# avg_session_length_log                0.340254             0.116526
#
#                               total_sessions_log  avg_session_length_log
# total_spend                             0.204204                0.077570
# total_events                            0.635699                0.255801
# total_sessions                          0.782182                0.181336
# avg_session_length                      0.085964                0.570257
# sd_session_length                       0.163273                0.685703
# avg_interactions_per_session           -0.087016                0.320714
# sd_interactions_per_session             0.383093                0.268427
# max_interactions_per_session            0.430422                0.311904
# purchase_pct_of_total_events           -0.613472               -0.296796
# view_pct_of_total_events                0.578633                0.206277
# cart_pct_of_total_events               -0.435057               -0.099382
# avg_purchases_per_session              -0.608130               -0.009394
# sd_purchases_per_session                0.219046                0.027429
# cart_events                             0.420304                0.211226
# purchase_events                         0.316896                0.097286
# sessions_with_purchase                  0.367864                0.090265
# sessions_with_cart                      0.506261                0.175449
# sessions_with_view                      0.783236                0.162298
# pct_sessions_end_purchase              -0.774152               -0.083607
# pct_sessions_end_cart                   0.225033                0.079523
# total_spend_log                         0.133369                0.026784
# total_events_log                        0.868504                0.340254
# purchase_events_log                     0.419871                0.116526
# total_sessions_log                      1.000000                0.159817
# avg_session_length_log                  0.159817                1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# ### Test out different combinations of features and outputs
#
# Here we test out models in order to find the best combination of features.

# %%
print("** All original inputs, original output **")
# For comparison, with all inputs. If you use T_total_spend_log for this one as the response instead, the adjusted R^2 is about .1
# Comprehensive
inputCols = ["total_spend", "total_events", "total_sessions", "avg_session_length", "sd_session_length", "avg_interactions_per_session", 
             "sd_interactions_per_session", "max_interactions_per_session", "purchase_pct_of_total_events", "view_pct_of_total_events",
             "cart_pct_of_total_events", "avg_purchases_per_session", "sd_purchases_per_session", "cart_events", "purchase_events", 
             "sessions_with_purchase", "sessions_with_cart", "sessions_with_view", "pct_sessions_end_purchase", 
             "pct_sessions_end_cart", "total_spend_log", "total_events_log", "purchase_events_log", "total_sessions_log",
             "avg_session_length_log"]

outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** All original inputs, original output **
# Model coefficients
#                      Column name  Coefficient       pValues
# 0                      intercept   423.176077  0.000000e+00
# 1                    total_spend   959.039237  1.100538e-01
# 2                   total_events   -18.103645  0.000000e+00
# 3                 total_sessions   729.648895  7.544119e-02
# 4             avg_session_length   -13.818762  3.463034e-10
# 5              sd_session_length    59.255441  3.439369e-01
# 6   avg_interactions_per_session    -8.792587  2.841095e-01
# 7    sd_interactions_per_session   -12.175377  7.300872e-02
# 8   max_interactions_per_session    24.406808  1.000000e+00
# 9   purchase_pct_of_total_events   157.067100  9.999936e-01
# 10      view_pct_of_total_events   392.046266  1.000000e+00
# 11      cart_pct_of_total_events   220.883964  0.000000e+00
# 12     avg_purchases_per_session  -134.142461  4.582408e-05
# 13      sd_purchases_per_session   -34.303431  3.564709e-10
# 14                   cart_events    72.951649  0.000000e+00
# 15               purchase_events   171.727878  7.487233e-11
# 16        sessions_with_purchase  -141.281192  0.000000e+00
# 17            sessions_with_cart   177.838678  0.000000e+00
# 18            sessions_with_view  -723.348505  1.291235e-01
# 19     pct_sessions_end_purchase    29.395292  1.328552e-07
# 20         pct_sessions_end_cart   -35.470491  1.326929e-07
# 21               total_spend_log   -30.654806  1.189769e-02
# 22              total_events_log   -67.496651  3.680123e-11
# 23           purchase_events_log    99.165064  1.615693e-02
# 24            total_sessions_log   -73.759725  2.344574e-04
# 25        avg_session_length_log   -26.900528  0.000000e+00
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +------------------+------------------+
# |     T_total_spend|        prediction|
# +------------------+------------------+
# |               0.0| 98.00925519362596|
# |               0.0|125.67773290706867|
# |               0.0| 88.74227233383743|
# |               0.0| 152.0085014682432|
# |               0.0| 96.17474033699642|
# |               0.0| 58.50395788579942|
# | 312.4200134277344|-28.93438101746011|
# |  6009.78010559082| 591.8934558885852|
# |1627.1900024414062|206.13389768683052|
# |1393.8800354003906| 150.9652478776609|
# +------------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, total_spend: double, total_events: bigint, total_sessions: bigint, T_total_spend: double, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, avg_session_length_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, unscaled_features: vector, features: vector, prediction: double]
# RMSE is 2192.2
# R^2 is 0.20848
# Adjusted R^2 is 0.20821

# %%
# Redo, iteratively removing & adding features to find the best combination. In the real world, 
# sacraficing a fraction of a percent of performance to dramatically reduce the number of features can be very useful. 
# Intermediate stages not shown because this was all done in the same cell. 

### Put this through cv below. It chose regparam = 0, sending some of these to 0, so they were removed from the final model. 
print("** Champion features, original output **")
inputCols = ["total_spend", "total_events", "total_sessions", "avg_session_length", "sd_session_length",
             "cart_pct_of_total_events", "avg_purchases_per_session", "sd_purchases_per_session", "cart_events", "purchase_events", 
             "sessions_with_purchase", "sessions_with_cart", "sessions_with_view", "pct_sessions_end_purchase", 
             "pct_sessions_end_cart", "total_spend_log", "total_events_log", "purchase_events_log", "total_sessions_log"]
#"view_events" breaks it - probably because it creates a linear combination when added :)
outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** Champion features, original output **
# Model coefficients
#                   Column name  Coefficient       pValues
# 0                   intercept   423.176077  0.000000e+00
# 1                 total_spend   958.357005  8.912611e-02
# 2                total_events   -14.848439  0.000000e+00
# 3              total_sessions   722.700369  7.938251e-02
# 4          avg_session_length   -13.635267  3.129694e-07
# 5           sd_session_length    40.949070  1.898210e-07
# 6    cart_pct_of_total_events   -38.377257  0.000000e+00
# 7   avg_purchases_per_session  -141.221003  2.229956e-06
# 8    sd_purchases_per_session   -37.828465  1.185112e-10
# 9                 cart_events    74.626408  0.000000e+00
# 10            purchase_events   175.317209  3.190048e-11
# 11     sessions_with_purchase  -142.707805  0.000000e+00
# 12         sessions_with_cart   174.569769  0.000000e+00
# 13         sessions_with_view  -717.313050  3.410221e-01
# 14  pct_sessions_end_purchase    17.228519  2.475769e-07
# 15      pct_sessions_end_cart   -34.514875  1.403645e-07
# 16            total_spend_log   -30.585153  5.295172e-07
# 17           total_events_log   -62.319306  7.329870e-11
# 18        purchase_events_log    96.568098  3.854896e-03
# 19         total_sessions_log   -68.244441  0.000000e+00
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +------------------+------------------+
# |     T_total_spend|        prediction|
# +------------------+------------------+
# |               0.0| 97.80758233598641|
# |               0.0|118.74569632401534|
# |               0.0| 81.30644184069911|
# |               0.0| 159.6522092588403|
# |               0.0| 63.76909911728245|
# |               0.0|59.591992819033976|
# | 312.4200134277344|-39.19793053661704|
# |  6009.78010559082| 573.7051384843095|
# |1627.1900024414062|199.54249892832019|
# |1393.8800354003906|136.71340551265882|
# +------------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, total_spend: double, total_events: bigint, total_sessions: bigint, T_total_spend: double, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, avg_session_length_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, unscaled_features: vector, features: vector, prediction: double]
# RMSE is 2192.0
# R^2 is 0.20869
# Adjusted R^2 is 0.20848

# %%
# Turns out, almost all of our performance is given by total_spend
print("** One input, original output **")
inputCols = ["total_spend"]
             
#"view_events" breaks it - probably because it creates a linear combination when added :)
outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** One input, original output **
# Model coefficients
#    Column name  Coefficient  pValues
# 0    intercept   423.176077      0.0
# 1  total_spend  1127.862791      0.0
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +------------------+------------------+
# |     T_total_spend|        prediction|
# +------------------+------------------+
# |               0.0| 88.44964229068427|
# |               0.0| 59.72016388535616|
# |               0.0| 48.47638984971593|
# |               0.0|129.85495440029206|
# |               0.0| 166.4244580091202|
# |               0.0| 57.01169580682296|
# | 312.4200134277344| 97.79956244132069|
# |  6009.78010559082| 698.6332202129912|
# |1627.1900024414062| 74.39881482764747|
# |1393.8800354003906|128.29836363018774|
# +------------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, total_spend: double, total_events: bigint, total_sessions: bigint, T_total_spend: double, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, avg_session_length_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, unscaled_features: vector, features: vector, prediction: double]
# RMSE is 2202.7
# R^2 is 0.20092
# Adjusted R^2 is 0.20091

# %% [markdown]
# ### Hyperparameter tuning on best features:

# %%
# pvalues breaks when used with this so taking that out
def modelInfo2(inputCols, pipelineModel):
    # Create a zipped list containing the coefficients and the data
    modelCols = copy.deepcopy(inputCols)
    modelCoeffs = list(pipelineModel.stages[-1].coefficients)
    modelCoeffs.insert(0,pipelineModel.stages[-1].intercept)
    modelCols.insert(0,"intercept")
    modelZippedList = list(map(list, zip(modelCols, modelCoeffs)))
        
    # Create the pandas DataFrame
    modelDF = pd.DataFrame(modelZippedList, columns = ['Column name', 'Coefficient'])
    
    return modelDF

# %% [markdown]
# # CHAMPION MODEL
# ### Test out different combinations of hyperparameters
#
# Here we test out 25 combinations of hyperparameters on our best linear regression model under cross validation.
#
# - Regularization parameters: [0, 0.01, 0.2, 1, 10]
# - Amount of LASSO-ness: [0, 0.25, 0.5, 0.75, 1]

# %%
# %%time
print("** Champion Model **")
inputCols = ["total_spend", "sd_session_length",
             "cart_pct_of_total_events", "avg_purchases_per_session", "cart_events", "purchase_events", 
             "sessions_with_cart", "sessions_with_view", 
             "pct_sessions_end_cart", "total_events_log"]

outputCol = "T_total_spend"
# Below creation of pipeline is necessary for crossval to run. I wonder if there's a way to get it to run on the generate pipeline fn? 
vecAssembler = VectorAssembler(inputCols=inputCols, outputCol="unscaled_features")
#Scale features
ss = StandardScaler(inputCol = "unscaled_features", outputCol = "features", withMean = True, withStd = True)
# Select output column for linear regression
lr = LinearRegression(featuresCol="features", labelCol="T_total_spend")

pipeline = Pipeline(stages=[vecAssembler, ss, lr])
    
paramGrid = ParamGridBuilder() \
    .addGrid(lr.regParam, [0, 0.01, 0.2, 1, 10]) \
    .addGrid(lr.elasticNetParam, [0, 0.25, 0.5, 0.75, 1]) \
    .build()

crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=RegressionEvaluator().setLabelCol("T_total_spend"),
                          numFolds=4)

# Run cross-validation, and choose the best set of parameters.
cvModel = crossval.setParallelism(8).fit(trainDF)
# Out:
# ** Champion Model **
# CPU times: user 3.94 s, sys: 806 ms, total: 4.75 s
# Wall time: 2min 21s

# %%
print("Best model coefficients")
print(modelInfo2(inputCols, cvModel.bestModel))


evaluationMetrics = getEvaluationMetrics(cvModel.bestModel,"T_total_spend",testDF,inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")

print()

print(cvModel.getEstimatorParamMaps()[np.argmax(cvModel.avgMetrics)])
print()
print(cvModel.avgMetrics)
# Out:
# Best model coefficients
#                   Column name  Coefficient
# 0                   intercept   423.176077
# 1                 total_spend   945.620418
# 2           sd_session_length    37.008892
# 3    cart_pct_of_total_events   -29.968641
# 4   avg_purchases_per_session   -59.315484
# 5                 cart_events    98.199506
# 6             purchase_events    17.886250
# 7          sessions_with_cart   214.567903
# 8          sessions_with_view   -29.259443
# 9       pct_sessions_end_cart   -36.063384
# 10           total_events_log   -74.075208
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +------------------+-------------------+
# |     T_total_spend|         prediction|
# +------------------+-------------------+
# |               0.0|  96.93146014143309|
# |               0.0|  71.14974932833758|
# |               0.0| -6.397339358116994|
# |               0.0| 158.54518067553505|
# |               0.0| 16.040471542388445|
# |               0.0|0.21607380805846788|
# | 312.4200134277344| -32.53853729089724|
# |  6009.78010559082|   623.068943360397|
# |1627.1900024414062| 161.61058678277726|
# |1393.8800354003906| 134.90276739221417|
# +------------------+-------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, total_spend: double, total_events: bigint, total_sessions: bigint, T_total_spend: double, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, avg_session_length_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, unscaled_features: vector, features: vector, prediction: double]
# RMSE is 2196.1
# R^2 is 0.20570
# Adjusted R^2 is 0.20559
#
# {Param(parent='LinearRegression_dc7300a34ae1', name='regParam', doc='regularization parameter (>= 0).'): 10.0, Param(parent='LinearRegression_dc7300a34ae1', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 1.0}
#
# [2258.898928099538, 2258.898928099538, 2258.898928099538, 2258.898928099538, 2258.898928099538, 2258.8988041120842, 2258.898457093996, 2258.911238412897, 2258.901370916002, 2258.8956356893495, 2258.896453610564, 2258.8925016259245, 2258.896648951833, 2258.900791933722, 2258.880890924842, 2258.8866659085406, 2258.8674476829005, 2258.8509030465507, 2258.8366343977623, 2258.823209876221, 2258.7881940265806, 2258.680481809485, 2258.666996814347, 2258.769387893122, 2258.912021416363]

# %% [markdown]
# ### Single predictor CV

# %%
# %%time
print("** Single Predictor **")
inputCols = ["total_spend"]

outputCol = "T_total_spend"
# Below creation of pipeline is necessary for crossval to run. I wonder if there's a way to get it to run on the generate pipeline fn? 
vecAssembler = VectorAssembler(inputCols=inputCols, outputCol="features")
#ss = StandardScaler(inputCol = "inputCols", outputCol = "features", withMean = True, withStd = False) #Doesn't work with one feature :)
# Select output column for linear regression
lr = LinearRegression(featuresCol="features", labelCol="T_total_spend")

pipeline = Pipeline(stages=[vecAssembler, lr])
    
paramGrid = ParamGridBuilder() \
    .addGrid(lr.regParam, [0, 0.01, 0.2, 1, 10]) \
    .addGrid(lr.elasticNetParam, [0, 0.25, 0.5, 0.75, 1]) \
    .build()

crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=RegressionEvaluator().setLabelCol("T_total_spend"),
                          numFolds=4)

# Run cross-validation, and choose the best set of parameters.
cvModel = crossval.setParallelism(8).fit(trainDF)
# Out:
# ** Single Predictor **
# CPU times: user 2.84 s, sys: 578 ms, total: 3.42 s
# Wall time: 2min 24s

# %%
print("Single Predictor coefficients")
print(modelInfo2(inputCols, cvModel.bestModel))


evaluationMetrics = getEvaluationMetrics(cvModel.bestModel,"T_total_spend",testDF,inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")

print()

print(cvModel.getEstimatorParamMaps()[np.argmax(cvModel.avgMetrics)])
print()
print(cvModel.avgMetrics)
# Out:
# Single Predictor coefficients
#    Column name  Coefficient
# 0    intercept    47.187462
# 1  total_spend     0.516834
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +------------------+------------------+
# |     T_total_spend|        prediction|
# +------------------+------------------+
# |               0.0| 89.75906626702661|
# |               0.0|61.141975363855934|
# |               0.0|49.942186104439656|
# |               0.0| 131.0024039913568|
# |               0.0| 167.4288505245308|
# |               0.0| 58.44410260340425|
# | 312.4200134277344| 99.07241025166809|
# |  6009.78010559082|  697.555653126959|
# |1627.1900024414062| 75.76320455657108|
# |1393.8800354003906|129.45190248420616|
# +------------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, total_spend: double, total_events: bigint, total_sessions: bigint, T_total_spend: double, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, avg_session_length_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, features: vector, prediction: double]
# RMSE is 2202.9
# R^2 is 0.20075
# Adjusted R^2 is 0.20074
#
# {Param(parent='LinearRegression_a6acb010b4a0', name='regParam', doc='regularization parameter (>= 0).'): 10.0, Param(parent='LinearRegression_a6acb010b4a0', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 1.0}
#
# [2267.169083262816, 2267.169083262816, 2267.169083262816, 2267.169083262816, 2267.169083262816, 2267.169064433132, 2267.1690646225416, 2267.1690648127997, 2267.1690650039027, 2267.1690651958515, 2267.168708360907, 2267.1687133337314, 2267.1687186449008, 2267.168724294456, 2267.168730282439, 2267.1672443430934, 2267.1672941383017, 2267.1673523993977, 2267.167419131393, 2267.16749433931, 2267.1546673130865, 2267.157961408766, 2267.162110182043, 2267.167118674995, 2267.1729919586605]

# %% [markdown]
# ## Other things we tried are below

# %% [markdown]
# ### Save pipeline model and get model size
# ##### CHECK NEW SIZE
# The model size is ____ kB, according to the file explorer in Linux.

# %%
pipelinePath = "models/lr-pipeline-model_NewData"
cvModel.bestModel.write().overwrite().save(pipelinePath)

# %% [markdown]
# #### Our data is extremely zero-inflated. If we downsample the data so our response variable =0 only about half the time, can we beat the model performance above? NO

# %%
# %%time
trainDF_ds = spark.read.parquet("./processed_data/ds_train.parquet")
testDF_ds = spark.read.parquet("./processed_data/ds_test.parquet")
# Out:
# CPU times: user 2.57 ms, sys: 147 µs, total: 2.72 ms
# Wall time: 452 ms

# %%
#"cart_pct_of_total_events" oddly this one breaks it? Not important, it's not a good predictor anyway

print("** Original + Log-transformed inputs, normal output **")
inputCols = ["total_spend", "total_events", "total_sessions", "avg_session_length", "sd_session_length", "avg_interactions_per_session", 
             "sd_interactions_per_session", "max_interactions_per_session", "purchase_pct_of_total_events", "view_pct_of_total_events",
             "avg_purchases_per_session", "sd_purchases_per_session", "cart_events", "purchase_events", 
             "sessions_with_purchase", "sessions_with_cart", "sessions_with_view", "pct_sessions_end_purchase", 
             "pct_sessions_end_cart", "total_spend_log", "total_events_log", "purchase_events_log", "total_sessions_log",
             "avg_session_length_log"]
outputCol = "T_total_spend"

pipeline = generatePipeline(inputCols, outputCol)
pipelineModel = pipeline.fit(trainDF_ds)

print("Model coefficients")
print(modelInfo(inputCols, pipelineModel))

evaluationMetrics = getEvaluationMetrics(pipelineModel,outputCol,testDF_ds, inputCols)
print(f"RMSE is {evaluationMetrics[0]:.1f}")
print(f"R^2 is {evaluationMetrics[1]:.5f}")
print(f"Adjusted R^2 is {evaluationMetrics[2]:.5f}")
# Out:
# ** Original + Log-transformed inputs, normal output **
# Model coefficients
#                      Column name  Coefficient       pValues
# 0                      intercept   838.205909  0.000000e+00
# 1                    total_spend  1445.836981  3.480280e-02
# 2                   total_events   -46.516061  9.139583e-02
# 3                 total_sessions   177.628187  1.250111e-01
# 4             avg_session_length   -24.427766  1.396487e-05
# 5              sd_session_length    86.003322  9.969550e-01
# 6   avg_interactions_per_session    -0.068504  4.946507e-01
# 7    sd_interactions_per_session   -14.918812  1.063055e-01
# 8   max_interactions_per_session    41.050507  4.625457e-01
# 9   purchase_pct_of_total_events   -18.679707  1.962957e-03
# 10      view_pct_of_total_events    65.627334  0.000000e+00
# 11     avg_purchases_per_session  -191.164887  5.555238e-01
# 12      sd_purchases_per_session    -9.398940  2.142610e-04
# 13                   cart_events    89.807460  0.000000e+00
# 14               purchase_events   347.047418  0.000000e+00
# 15        sessions_with_purchase  -551.419705  0.000000e+00
# 16            sessions_with_cart   428.481433  3.102853e-02
# 17            sessions_with_view  -213.368118  1.445857e-04
# 18     pct_sessions_end_purchase   135.589285  9.046360e-07
# 19         pct_sessions_end_cart   -62.961291  0.000000e+00
# 20               total_spend_log    96.467430  2.858073e-03
# 21              total_events_log  -158.072070  4.042090e-06
# 22           purchase_events_log   139.456648  2.568627e-01
# 23            total_sessions_log    66.517352  2.947038e-03
# 24        avg_session_length_log   -43.545902  0.000000e+00
#
# type preddf<class 'pyspark.sql.dataframe.DataFrame'>
#
# +------------------+------------------+
# |     T_total_spend|        prediction|
# +------------------+------------------+
# |               0.0|226.60767129994167|
# |               0.0| 151.5383438414956|
# |               0.0|-84.52131071831354|
# |               0.0|358.12816372507154|
# |               0.0|290.25896921223716|
# |               0.0| 41.05488887743354|
# | 312.4200134277344|  133.533170451945|
# |  6009.78010559082|1081.4803792560383|
# |1627.1900024414062|337.41513451971343|
# |1393.8800354003906| 355.8281881959083|
# +------------------+------------------+
# only showing top 10 rows
#
# DataFrame[user_id: int, total_spend: double, total_events: bigint, total_sessions: bigint, T_total_spend: double, avg_session_length: double, sd_session_length: double, avg_interactions_per_session: double, sd_interactions_per_session: double, max_interactions_per_session: bigint, purchase_pct_of_total_events: double, view_pct_of_total_events: double, cart_pct_of_total_events: double, avg_purchases_per_session: double, sd_purchases_per_session: double, cart_events: bigint, purchase_events: bigint, view_events: bigint, sessions_with_purchase: bigint, sessions_with_cart: bigint, sessions_with_view: bigint, pct_sessions_end_purchase: double, pct_sessions_end_cart: double, total_spend_log: double, total_events_log: double, purchase_events_log: double, total_sessions_log: double, avg_session_length_log: double, T_total_spend_log: double, pca_purchases10: vector, pca_purchases20: vector, pca_purchases50: vector, pca_purchases100: vector, unscaled_features: vector, features: vector, prediction: double]
# RMSE is 2217.7
# R^2 is 0.19003
# Adjusted R^2 is 0.18976

# %% [markdown]
# #### Interestingly, downsampling the inflated 0s doesn't seem to help at all on the test set!
